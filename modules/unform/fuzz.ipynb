# %%
# Just the normal prequisites for using matplotlib and numpy in a Jupyter notebook
# %matplotlib inline
# Use the svg backend, in my opinion it just makes better looking plots
# %config InlineBackend.figure_format = 'svg'

import PySpice.Logging.Logging as Logging
logger = Logging.setup_logging( logging_level='DEBUG')

import os
import sys
import IPython
from scipy import signal
import scipy.fftpack
from PySpice.Unit import *
from PySpice.Spice.Parser import SpiceParser
from PySpice.Spice.Netlist import Circuit, SubCircuit, SubCircuitFactory
from PySpice.Spice.Library import SpiceLibrary
from PySpice.Probe.Plot import plot
from PySpice.Plot.BodeDiagram import bode_diagram
from PySpice.Doc.ExampleTools import find_libraries
from PySpice.Math import *
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt
import unittest

sys.path.append('../../lib/python')
import Spice2Wav.Spice2Wav as wav

import PySpice.Logging.Logging as Logging
logger = Logging.setup_logging()

directory_path = Path(os.path.abspath('')).resolve().parent.parent
spice_libraries_path = directory_path.joinpath("lib", "spice")
spice_library = SpiceLibrary(spice_libraries_path)

directory_path = Path(os.path.abspath('')).resolve()
# Out:
# 2020-11-08 14:15:06,772 - PySpice.Spice.Netlist.__new__ - DEBUG - Element don't define a __pins__ attribute
# 2020-11-08 14:15:06,774 - PySpice.Spice.Netlist.__new__ - DEBUG - FixedPinElement don't define a __pins__ attribute
# 2020-11-08 14:15:06,776 - PySpice.Spice.Netlist.__new__ - DEBUG - SubCircuitElement don't define a __pins__ attribute
# 2020-11-08 14:15:06,777 - PySpice.Spice.Netlist.__new__ - DEBUG - Resistor don't define a __pins__ attribute
# 2020-11-08 14:15:06,778 - PySpice.Spice.Netlist.__new__ - DEBUG - SemiconductorResistor don't define a __pins__ attribute
# 2020-11-08 14:15:06,779 - PySpice.Spice.Netlist.__new__ - DEBUG - BehavioralResistor don't define a __pins__ attribute
# 2020-11-08 14:15:06,786 - PySpice.Spice.Netlist.__new__ - DEBUG - Capacitor don't define a __pins__ attribute
# 2020-11-08 14:15:06,788 - PySpice.Spice.Netlist.__new__ - DEBUG - SemiconductorCapacitor don't define a __pins__ attribute
# 2020-11-08 14:15:06,792 - PySpice.Spice.Netlist.__new__ - DEBUG - BehavioralCapacitor don't define a __pins__ attribute
# 2020-11-08 14:15:06,800 - PySpice.Spice.Netlist.__new__ - DEBUG - Inductor don't define a __pins__ attribute
# 2020-11-08 14:15:06,803 - PySpice.Spice.Netlist.__new__ - DEBUG - BehavioralInductor don't define a __pins__ attribute
# 2020-11-08 14:15:06,805 - PySpice.Spice.Netlist.__new__ - DEBUG - CoupledInductor don't define a __pins__ attribute
# 2020-11-08 14:15:06,808 - PySpice.Spice.Netlist.__new__ - DEBUG - VoltageControlledSwitch don't define a __pins__ attribute
# 2020-11-08 14:15:06,810 - PySpice.Spice.Netlist.__new__ - DEBUG - CurrentControlledSwitch don't define a __pins__ attribute
# 2020-11-08 14:15:06,811 - PySpice.Spice.Netlist.__new__ - DEBUG - VoltageSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,819 - PySpice.Spice.Netlist.__new__ - DEBUG - CurrentSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,823 - PySpice.Spice.Netlist.__new__ - DEBUG - VoltageControlledCurrentSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,826 - PySpice.Spice.Netlist.__new__ - DEBUG - VoltageControlledVoltageSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,827 - PySpice.Spice.Netlist.__new__ - DEBUG - CurrentControlledCurrentSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,835 - PySpice.Spice.Netlist.__new__ - DEBUG - CurrentControlledVoltageSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,841 - PySpice.Spice.Netlist.__new__ - DEBUG - BehavioralSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,843 - PySpice.Spice.Netlist.__new__ - DEBUG - NonLinearVoltageSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,847 - PySpice.Spice.Netlist.__new__ - DEBUG - NonLinearCurrentSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,853 - PySpice.Spice.Netlist.__new__ - DEBUG - JunctionFieldEffectTransistor don't define a __pins__ attribute
# 2020-11-08 14:15:06,857 - PySpice.Spice.Netlist.__new__ - DEBUG - Mesfet don't define a __pins__ attribute
# 2020-11-08 14:15:06,860 - PySpice.Spice.Netlist.__new__ - DEBUG - LosslessTransmissionLine don't define a __pins__ attribute
# 2020-11-08 14:15:06,862 - PySpice.Spice.Netlist.__new__ - DEBUG - LossyTransmission don't define a __pins__ attribute
# 2020-11-08 14:15:06,863 - PySpice.Spice.Netlist.__new__ - DEBUG - CoupledMulticonductorLine don't define a __pins__ attribute
# 2020-11-08 14:15:06,865 - PySpice.Spice.Netlist.__new__ - DEBUG - SingleLossyTransmissionLine don't define a __pins__ attribute
# 2020-11-08 14:15:06,867 - PySpice.Spice.Netlist.__new__ - DEBUG - XSpiceElement don't define a __pins__ attribute
# 2020-11-08 14:15:06,874 - PySpice.Spice.Netlist.__new__ - DEBUG - GSSElement don't define a __pins__ attribute
# 2020-11-08 14:15:06,878 - PySpice.Spice.Netlist.__new__ - DEBUG - SinusoidalVoltageSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,879 - PySpice.Spice.Netlist.__new__ - DEBUG - SinusoidalCurrentSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,881 - PySpice.Spice.Netlist.__new__ - DEBUG - AcLine don't define a __pins__ attribute
# 2020-11-08 14:15:06,882 - PySpice.Spice.Netlist.__new__ - DEBUG - PulseVoltageSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,885 - PySpice.Spice.Netlist.__new__ - DEBUG - PulseCurrentSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,888 - PySpice.Spice.Netlist.__new__ - DEBUG - ExponentialVoltageSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,890 - PySpice.Spice.Netlist.__new__ - DEBUG - ExponentialCurrentSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,893 - PySpice.Spice.Netlist.__new__ - DEBUG - PieceWiseLinearVoltageSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,894 - PySpice.Spice.Netlist.__new__ - DEBUG - PieceWiseLinearCurrentSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,896 - PySpice.Spice.Netlist.__new__ - DEBUG - SingleFrequencyFMVoltageSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,897 - PySpice.Spice.Netlist.__new__ - DEBUG - SingleFrequencyFMCurrentSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,903 - PySpice.Spice.Netlist.__new__ - DEBUG - AmplitudeModulatedVoltageSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,905 - PySpice.Spice.Netlist.__new__ - DEBUG - AmplitudeModulatedCurrentSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,907 - PySpice.Spice.Netlist.__new__ - DEBUG - RandomVoltageSource don't define a __pins__ attribute
# 2020-11-08 14:15:06,908 - PySpice.Spice.Netlist.__new__ - DEBUG - RandomCurrentSource don't define a __pins__ attribute

# %% [markdown]
# ![module](https://img.shields.io/badge/module-shin%20ey-yellow) ![status](https://img.shields.io/badge/status-work%20in%20progress-orange)
#
# ## *shin ey*
#
# <a href="https://photos.app.goo.gl/pg6iZUC32rTKX5LC7"><img src="https://spielhuus.github.io/elektrophon/images/kontrast-logo-tmb.jpg" height="300px" align="right"></a>
#
# ***table of contents***
#
# * [*about*](#about)
# * [*construction*](#construction)
# * [*calibration*](#calibration)
# * [*usage*](#usage)
# * [*credits*](#credits)
# * [*links*](#links)
# * [*changelog*](#changelog)
#
# <br/><br/><br/><br/>
#
# ## *about*
#
# pegel is a voltage controlled amplifier (vca). there are various designs to implement a vca. rod elliott (ESP) has an article on vca techniques [[1][1]]. diy synthesizer modules are usualy designed with an integrated vca chip [[2][2]]  or with a differential amplifier [[3][3]]. the integrated vca chips are either obsolete or rather expensive. the differential amplifier can be built with transistors only. the design has some downsides. even in the simulation the result is not symetryc and has a dc offset from the control voltage. this needs a lot of trimming to get an accurate result. but the biggest downside is, that this design can not do proper amplitude modulation (am). when the carrier signal goes below zero the base signal is completely muted.

# %% [markdown]
# ### input mixer
#
# this  is  a pasive input mixer.

# %%
#load the input mixer schema
kicad_netlist_path = directory_path.joinpath('main', 'Input Mixer.cir')
parser = SpiceParser(path=str(kicad_netlist_path))


#simulate input
input_mixer = parser.build_circuit(ground=5)
input_mixer.include(spice_library['BC846B'])
input_mixer.V('1', '+15V', input_mixer.gnd, 'DC 15')
input_mixer.V('2', '-15V', input_mixer.gnd, 'DC -15')
input_mixer.V('3', 'NC_01', input_mixer.gnd, 'DC 0V AC 2V SIN(0 5V 1k)')
input_mixer.V('4', 'NC_02', input_mixer.gnd, 'DC 0V AC 2V SIN(0 5V 1k 0 0 90)')

class VoltageDivider(SubCircuitFactory):
    __name__ = 'voltage_divider'
    __nodes__ = ('n1', 'n2', 'n3' )
    def __init__(self, R=100@u_kΩ, w=0.5):
        super().__init__()
        self.R(1, 'n1', 'n2', R * w)
        self.R(2, 'n2', 'n3', R * (1.0-w) )

input_mixer.subcircuit(VoltageDivider(R=100@u_kΩ, w=0.4))

simulator = input_mixer.simulator(temperature=25, nominal_temperature=25)
analysis_input_mixer = simulator.transient(step_time=1@u_us, start_time=100@u_ms, end_time=110@u_ms)
# Out:
# 2020-11-08 14:15:07,032 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.new_instance - DEBUG - New instance for id 0
# 2020-11-08 14:15:07,036 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._load_library - DEBUG - Set locale LC_NUMERIC to C
# 2020-11-08 14:15:07,107 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._load_library - DEBUG - Load library libngspice.so
# 2020-11-08 14:15:07,143 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stderr Error: bad type for debug var'
# 2020-11-08 14:15:07,144 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Error: bad type for debug var
# 2020-11-08 14:15:07,147 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stderr Warning: ngspice compiled without debug messages'
# 2020-11-08 14:15:07,148 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - WARNING - Warning: ngspice compiled without debug messages
# 2020-11-08 14:15:07,151 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ******'
# 2020-11-08 14:15:07,153 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** ngspice-31 shared library'
# 2020-11-08 14:15:07,155 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** Creation Date: Sun Oct 27 09:07:06 UTC 2019'
# 2020-11-08 14:15:07,156 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ******'
# 2020-11-08 14:15:07,168 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: version -f
# 2020-11-08 14:15:07,170 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ******'
# 2020-11-08 14:15:07,175 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** ngspice-31 : Circuit level simulation program'
# 2020-11-08 14:15:07,176 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** The U. C. Berkeley CAD Group'
# 2020-11-08 14:15:07,179 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** Copyright 1985-1994, Regents of the University of California.'
# 2020-11-08 14:15:07,183 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** Please get your ngspice manual from http://ngspice.sourceforge.net/docs.html'
# 2020-11-08 14:15:07,186 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** Please file your bug-reports at http://ngspice.sourceforge.net/bugrep.html'
# 2020-11-08 14:15:07,188 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** Creation Date: Sun Oct 27 09:07:06 UTC 2019'
# 2020-11-08 14:15:07,189 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout **'
# 2020-11-08 14:15:07,190 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** CIDER 1.b1 (CODECS simulator) included'
# 2020-11-08 14:15:07,193 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** XSPICE extensions included'
# 2020-11-08 14:15:07,196 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b"stdout ** Relevant compilation options (refer to user's manual):"
# 2020-11-08 14:15:07,200 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** OpenMP multithreading for BSIM3, BSIM4 enabled'
# 2020-11-08 14:15:07,202 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** X11 interface not compiled into ngspice'
# 2020-11-08 14:15:07,207 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout **'
# 2020-11-08 14:15:07,211 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ******'
# 2020-11-08 14:15:07,215 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._get_version - DEBUG - Ngspice version 31 with extensions: CIDER, XSPICE
# 2020-11-08 14:15:07,219 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: set nomoremode
# 2020-11-08 14:15:07,227 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 40.0kOhm
# R2 n2 n3 60.0kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:07,231 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-08 14:15:07,235 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 40.0kOhm
# R2 n2 n3 60.0kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:07,253 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-08 14:15:07,255 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Warning: Model issue on line 11 :'
# 2020-11-08 14:15:07,258 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout .model bc846b npn(is=1.82e-14 nf=0.9932 ise=2.89e-16 ne=1.4 bf=324.4 ikf ...'
# 2020-11-08 14:15:07,261 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (vceo) - ignored'
# 2020-11-08 14:15:07,262 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (icrating) - ignored'
# 2020-11-08 14:15:07,264 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-08 14:15:07,266 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-08 14:15:07,274 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-08 14:15:07,278 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-08 14:15:07,280 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-08 14:15:07,282 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-08 14:15:07,285 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad2_                               0'
# 2020-11-08 14:15:07,286 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_01                                        0'
# 2020-11-08 14:15:07,288 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad2_                               2'
# 2020-11-08 14:15:07,289 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_02                                        5'
# 2020-11-08 14:15:07,295 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q9-pad3_                         -14.9997'
# 2020-11-08 14:15:07,296 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout -15v                                       -15'
# 2020-11-08 14:15:07,300 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q10-pad3_                        -14.9997'
# 2020-11-08 14:15:07,304 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q11-pad2_                        -14.9997'
# 2020-11-08 14:15:07,305 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +15v                                        15'
# 2020-11-08 14:15:07,306 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad1_                        -14.6531'
# 2020-11-08 14:15:07,308 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad1_                        -14.6531'
# 2020-11-08 14:15:07,312 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad2_                             -15'
# 2020-11-08 14:15:07,313 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad1_                         7.04708'
# 2020-11-08 14:15:07,318 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout /mixer_in                              6.33732'
# 2020-11-08 14:15:07,320 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v4#branch                               -5e-05'
# 2020-11-08 14:15:07,322 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v3#branch                                    0'
# 2020-11-08 14:15:07,323 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                            0.0142249'
# 2020-11-08 14:15:07,324 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                           -0.0142954'
# 2020-11-08 14:15:09,230 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00001e-01\r'
# 2020-11-08 14:15:09,478 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10001'
# 2020-11-08 14:15:09,479 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-08 14:15:09,480 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']

# %%
#plot the results
fig, axis = plt.subplots(figsize=(18, 6))

#plot mixed signal
axis.plot(analysis_input_mixer['NC_01'].abscissa*1000, analysis_input_mixer['NC_01'], c='grey') 
axis.plot(analysis_input_mixer['NC_02'].abscissa*1000, analysis_input_mixer['NC_02'], c='grey') 
axis.plot(analysis_input_mixer['/MIXER_IN'].abscissa*1000, analysis_input_mixer['/MIXER_IN'], c='orange') 
axis.grid()
axis.set_xlabel('t [ms]')
axis.set_ylabel('[V]')
axis.set_title('mixed imput saignal', y=-0.2)

plt.show()
# Out:
# 2020-11-08 14:15:09,573 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'multiply'> is NEW_UNIT
# 2020-11-08 14:15:09,583 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'multiply'> is NEW_UNIT
# 2020-11-08 14:15:09,591 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'multiply'> is NEW_UNIT

# %%
for step in np.arange(0, 1, 0.1) :
    #load the input mixer schema
    kicad_netlist_path = directory_path.joinpath('main', 'Input Mixer.cir')
    parser = SpiceParser(path=str(kicad_netlist_path))


    #simulate input
    input_mixer = parser.build_circuit(ground=5)
    input_mixer.include(spice_library['BC846B'])
    input_mixer.V('1', '+15V', input_mixer.gnd, 'DC 15')
    input_mixer.V('2', '-15V', input_mixer.gnd, 'DC -15')
    input_mixer.V('3', 'NC_01', input_mixer.gnd, 'DC 0V AC 2V SIN(0 5V 1k)')
    input_mixer.V('4', 'NC_02', input_mixer.gnd, 'DC 0V AC 2V SIN(0 5V 1k 0 0 90)')

    class VoltageDivider(SubCircuitFactory):
        __name__ = 'voltage_divider'
        __nodes__ = ('n1', 'n2', 'n3' )
        def __init__(self, R=100@u_kΩ, w=0.5):
            super().__init__()
            self.R(1, 'n1', 'n2', R * w)
            self.R(2, 'n2', 'n3', R * (1.0-w) )

    input_mixer.subcircuit(VoltageDivider(R=100@u_kΩ, w=step))

    simulator = input_mixer.simulator(temperature=25, nominal_temperature=25)
    analysis_input_mixer = simulator.transient(step_time=1@u_us, start_time=100@u_ms, end_time=110@u_ms)

    mixer_max = np.max(np.array(analysis_input_mixer['/MIXER_IN']))
    mixer_min = np.min(np.array(analysis_input_mixer['/MIXER_IN']))
    mixer_average = np.average(np.array(analysis_input_mixer['/MIXER_IN']))

    print( 'Voltages: Max: %f, Min: %f, p2p: %f, Average: %f ' % (mixer_max, mixer_min, mixer_max-mixer_min, mixer_average))
# Out:
# 2020-11-08 14:15:09,984 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 0.0kOhm
# R2 n2 n3 100.0kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:09,986 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-08 14:15:09,990 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 0.0kOhm
# R2 n2 n3 100.0kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:09,995 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-08 14:15:09,999 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Warning: Model issue on line 11 :'
# 2020-11-08 14:15:10,003 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout .model bc846b npn(is=1.82e-14 nf=0.9932 ise=2.89e-16 ne=1.4 bf=324.4 ikf ...'
# 2020-11-08 14:15:10,004 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (vceo) - ignored'
# 2020-11-08 14:15:10,006 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (icrating) - ignored'
# 2020-11-08 14:15:10,008 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-08 14:15:10,011 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-08 14:15:10,020 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-08 14:15:10,025 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-08 14:15:10,030 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-08 14:15:10,036 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-08 14:15:10,039 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad2_                               0'
# 2020-11-08 14:15:10,040 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_01                                        0'
# 2020-11-08 14:15:10,042 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad2_                           5e-08'
# 2020-11-08 14:15:10,048 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_02                                        5'
# 2020-11-08 14:15:10,049 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q9-pad3_                         -14.9997'
# 2020-11-08 14:15:10,051 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout -15v                                       -15'
# 2020-11-08 14:15:10,052 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q10-pad3_                        -14.9997'
# 2020-11-08 14:15:10,054 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q11-pad2_                        -14.9997'
# 2020-11-08 14:15:10,060 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +15v                                        15'
# 2020-11-08 14:15:10,063 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad1_                        -14.6531'
# 2020-11-08 14:15:10,065 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad1_                        -14.6531'
# 2020-11-08 14:15:10,068 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad2_                             -15'
# 2020-11-08 14:15:10,069 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad1_                         7.04708'
# 2020-11-08 14:15:10,071 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout /mixer_in                              6.33732'
# 2020-11-08 14:15:10,073 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v4#branch                               -5e-05'
# 2020-11-08 14:15:10,075 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v3#branch                                    0'
# 2020-11-08 14:15:10,077 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                            0.0142249'
# 2020-11-08 14:15:10,079 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                           -0.0142954'
# 2020-11-08 14:15:11,938 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00000e-01\r'
# 2020-11-08 14:15:12,155 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10001'
# 2020-11-08 14:15:12,156 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-08 14:15:12,157 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']
# Voltages: Max: 6.337322, Min: 6.337322, p2p: 0.000000, Average: 6.337322
# 2020-11-08 14:15:12,171 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 10.0kOhm
# R2 n2 n3 90.0kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:12,175 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-08 14:15:12,180 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 10.0kOhm
# R2 n2 n3 90.0kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:12,187 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-08 14:15:12,189 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Warning: Model issue on line 11 :'
# 2020-11-08 14:15:12,195 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout .model bc846b npn(is=1.82e-14 nf=0.9932 ise=2.89e-16 ne=1.4 bf=324.4 ikf ...'
# 2020-11-08 14:15:12,197 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (vceo) - ignored'
# 2020-11-08 14:15:12,199 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (icrating) - ignored'
# 2020-11-08 14:15:12,202 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-08 14:15:12,205 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-08 14:15:12,213 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-08 14:15:12,216 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-08 14:15:12,218 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-08 14:15:12,220 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-08 14:15:12,225 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad2_                               0'
# 2020-11-08 14:15:12,226 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_01                                        0'
# 2020-11-08 14:15:12,228 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad2_                             0.5'
# 2020-11-08 14:15:12,229 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_02                                        5'
# 2020-11-08 14:15:12,233 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q9-pad3_                         -14.9997'
# 2020-11-08 14:15:12,237 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout -15v                                       -15'
# 2020-11-08 14:15:12,241 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q10-pad3_                        -14.9997'
# 2020-11-08 14:15:12,246 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q11-pad2_                        -14.9997'
# 2020-11-08 14:15:12,251 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +15v                                        15'
# 2020-11-08 14:15:12,256 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad1_                        -14.6531'
# 2020-11-08 14:15:12,259 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad1_                        -14.6531'
# 2020-11-08 14:15:12,263 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad2_                             -15'
# 2020-11-08 14:15:12,267 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad1_                         7.04708'
# 2020-11-08 14:15:12,274 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout /mixer_in                              6.33732'
# 2020-11-08 14:15:12,276 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v4#branch                               -5e-05'
# 2020-11-08 14:15:12,277 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v3#branch                                    0'
# 2020-11-08 14:15:12,279 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                            0.0142249'
# 2020-11-08 14:15:12,282 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                           -0.0142954'
# 2020-11-08 14:15:14,008 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00001e-01\r'
# 2020-11-08 14:15:14,237 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10001'
# 2020-11-08 14:15:14,238 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-08 14:15:14,239 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']
# Voltages: Max: 6.337346, Min: 6.337298, p2p: 0.000048, Average: 6.337322
# 2020-11-08 14:15:14,250 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 20.0kOhm
# R2 n2 n3 80.0kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:14,251 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-08 14:15:14,254 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 20.0kOhm
# R2 n2 n3 80.0kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:14,256 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-08 14:15:14,258 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Warning: Model issue on line 11 :'
# 2020-11-08 14:15:14,259 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout .model bc846b npn(is=1.82e-14 nf=0.9932 ise=2.89e-16 ne=1.4 bf=324.4 ikf ...'
# 2020-11-08 14:15:14,260 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (vceo) - ignored'
# 2020-11-08 14:15:14,262 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (icrating) - ignored'
# 2020-11-08 14:15:14,263 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-08 14:15:14,266 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-08 14:15:14,271 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-08 14:15:14,271 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-08 14:15:14,272 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-08 14:15:14,273 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-08 14:15:14,274 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad2_                               0'
# 2020-11-08 14:15:14,275 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_01                                        0'
# 2020-11-08 14:15:14,275 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad2_                               1'
# 2020-11-08 14:15:14,277 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_02                                        5'
# 2020-11-08 14:15:14,277 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q9-pad3_                         -14.9997'
# 2020-11-08 14:15:14,278 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout -15v                                       -15'
# 2020-11-08 14:15:14,282 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q10-pad3_                        -14.9997'
# 2020-11-08 14:15:14,286 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q11-pad2_                        -14.9997'
# 2020-11-08 14:15:14,288 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +15v                                        15'
# 2020-11-08 14:15:14,294 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad1_                        -14.6531'
# 2020-11-08 14:15:14,297 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad1_                        -14.6531'
# 2020-11-08 14:15:14,301 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad2_                             -15'
# 2020-11-08 14:15:14,302 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad1_                         7.04708'
# 2020-11-08 14:15:14,304 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout /mixer_in                              6.33732'
# 2020-11-08 14:15:14,304 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v4#branch                               -5e-05'
# 2020-11-08 14:15:14,305 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v3#branch                                    0'
# 2020-11-08 14:15:14,307 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                            0.0142249'
# 2020-11-08 14:15:14,309 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                           -0.0142954'
# 2020-11-08 14:15:16,152 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00001e-01\r'
# 2020-11-08 14:15:16,389 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10001'
# 2020-11-08 14:15:16,390 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-08 14:15:16,391 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']
# Voltages: Max: 6.340602, Min: 6.336957, p2p: 0.003645, Average: 6.337335
# 2020-11-08 14:15:16,400 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 30.000000000000004kOhm
# R2 n2 n3 70.0kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:16,402 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-08 14:15:16,407 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 30.000000000000004kOhm
# R2 n2 n3 70.0kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:16,409 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-08 14:15:16,412 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Warning: Model issue on line 11 :'
# 2020-11-08 14:15:16,415 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout .model bc846b npn(is=1.82e-14 nf=0.9932 ise=2.89e-16 ne=1.4 bf=324.4 ikf ...'
# 2020-11-08 14:15:16,417 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (vceo) - ignored'
# 2020-11-08 14:15:16,421 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (icrating) - ignored'
# 2020-11-08 14:15:16,423 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-08 14:15:16,431 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-08 14:15:16,433 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-08 14:15:16,436 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-08 14:15:16,438 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-08 14:15:16,439 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-08 14:15:16,441 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad2_                               0'
# 2020-11-08 14:15:16,444 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_01                                        0'
# 2020-11-08 14:15:16,448 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad2_                             1.5'
# 2020-11-08 14:15:16,454 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_02                                        5'
# 2020-11-08 14:15:16,455 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q9-pad3_                         -14.9997'
# 2020-11-08 14:15:16,457 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout -15v                                       -15'
# 2020-11-08 14:15:16,463 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q10-pad3_                        -14.9997'
# 2020-11-08 14:15:16,465 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q11-pad2_                        -14.9997'
# 2020-11-08 14:15:16,467 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +15v                                        15'
# 2020-11-08 14:15:16,469 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad1_                        -14.6531'
# 2020-11-08 14:15:16,472 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad1_                        -14.6531'
# 2020-11-08 14:15:16,474 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad2_                             -15'
# 2020-11-08 14:15:16,476 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad1_                         7.04708'
# 2020-11-08 14:15:16,480 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout /mixer_in                              6.33732'
# 2020-11-08 14:15:16,483 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v4#branch                               -5e-05'
# 2020-11-08 14:15:16,488 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v3#branch                                    0'
# 2020-11-08 14:15:16,490 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                            0.0142249'
# 2020-11-08 14:15:16,492 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                           -0.0142954'
# 2020-11-08 14:15:18,297 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00001e-01\r'
# 2020-11-08 14:15:18,547 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.08843e-01\r'
# 2020-11-08 14:15:18,586 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10001'
# 2020-11-08 14:15:18,588 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-08 14:15:18,590 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']
# Voltages: Max: 6.491569, Min: 6.309590, p2p: 0.181979, Average: 6.338889
# 2020-11-08 14:15:18,602 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 40.0kOhm
# R2 n2 n3 60.0kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:18,603 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-08 14:15:18,606 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 40.0kOhm
# R2 n2 n3 60.0kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:18,611 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-08 14:15:18,614 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Warning: Model issue on line 11 :'
# 2020-11-08 14:15:18,616 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout .model bc846b npn(is=1.82e-14 nf=0.9932 ise=2.89e-16 ne=1.4 bf=324.4 ikf ...'
# 2020-11-08 14:15:18,618 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (vceo) - ignored'
# 2020-11-08 14:15:18,620 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (icrating) - ignored'
# 2020-11-08 14:15:18,621 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-08 14:15:18,622 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-08 14:15:18,626 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-08 14:15:18,627 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-08 14:15:18,629 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-08 14:15:18,630 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-08 14:15:18,632 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad2_                               0'
# 2020-11-08 14:15:18,634 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_01                                        0'
# 2020-11-08 14:15:18,637 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad2_                               2'
# 2020-11-08 14:15:18,640 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_02                                        5'
# 2020-11-08 14:15:18,643 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q9-pad3_                         -14.9997'
# 2020-11-08 14:15:18,645 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout -15v                                       -15'
# 2020-11-08 14:15:18,647 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q10-pad3_                        -14.9997'
# 2020-11-08 14:15:18,651 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q11-pad2_                        -14.9997'
# 2020-11-08 14:15:18,652 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +15v                                        15'
# 2020-11-08 14:15:18,653 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad1_                        -14.6531'
# 2020-11-08 14:15:18,655 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad1_                        -14.6531'
# 2020-11-08 14:15:18,656 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad2_                             -15'
# 2020-11-08 14:15:18,657 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad1_                         7.04708'
# 2020-11-08 14:15:18,660 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout /mixer_in                              6.33732'
# 2020-11-08 14:15:18,664 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v4#branch                               -5e-05'
# 2020-11-08 14:15:18,665 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v3#branch                                    0'
# 2020-11-08 14:15:18,667 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                            0.0142249'
# 2020-11-08 14:15:18,673 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                           -0.0142954'
# 2020-11-08 14:15:20,660 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00001e-01\r'
# 2020-11-08 14:15:20,871 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10001'
# 2020-11-08 14:15:20,872 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-08 14:15:20,873 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']
# Voltages: Max: 6.689478, Min: 6.253249, p2p: 0.436229, Average: 6.342192
# 2020-11-08 14:15:20,882 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 50.0kOhm
# R2 n2 n3 50.0kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:20,886 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-08 14:15:20,889 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 50.0kOhm
# R2 n2 n3 50.0kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:20,891 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-08 14:15:20,894 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Warning: Model issue on line 11 :'
# 2020-11-08 14:15:20,895 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout .model bc846b npn(is=1.82e-14 nf=0.9932 ise=2.89e-16 ne=1.4 bf=324.4 ikf ...'
# 2020-11-08 14:15:20,900 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (vceo) - ignored'
# 2020-11-08 14:15:20,902 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (icrating) - ignored'
# 2020-11-08 14:15:20,904 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-08 14:15:20,909 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-08 14:15:20,911 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-08 14:15:20,913 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-08 14:15:20,918 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-08 14:15:20,923 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-08 14:15:20,926 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad2_                               0'
# 2020-11-08 14:15:20,928 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_01                                        0'
# 2020-11-08 14:15:20,929 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad2_                             2.5'
# 2020-11-08 14:15:20,935 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_02                                        5'
# 2020-11-08 14:15:20,937 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q9-pad3_                         -14.9997'
# 2020-11-08 14:15:20,943 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout -15v                                       -15'
# 2020-11-08 14:15:20,946 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q10-pad3_                        -14.9997'
# 2020-11-08 14:15:20,950 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q11-pad2_                        -14.9997'
# 2020-11-08 14:15:20,953 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +15v                                        15'
# 2020-11-08 14:15:20,956 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad1_                        -14.6531'
# 2020-11-08 14:15:20,957 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad1_                        -14.6531'
# 2020-11-08 14:15:20,960 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad2_                             -15'
# 2020-11-08 14:15:20,961 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad1_                         7.04708'
# 2020-11-08 14:15:20,962 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout /mixer_in                              6.33732'
# 2020-11-08 14:15:20,969 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v4#branch                               -5e-05'
# 2020-11-08 14:15:20,974 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v3#branch                                    0'
# 2020-11-08 14:15:20,976 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                            0.0142249'
# 2020-11-08 14:15:20,979 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                           -0.0142954'
# 2020-11-08 14:15:22,961 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00001e-01\r'
# 2020-11-08 14:15:23,208 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10001'
# 2020-11-08 14:15:23,210 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-08 14:15:23,211 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']
# Voltages: Max: 6.887506, Min: 6.186339, p2p: 0.701167, Average: 6.346095
# 2020-11-08 14:15:23,222 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 60.00000000000001kOhm
# R2 n2 n3 39.99999999999999kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:23,224 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-08 14:15:23,230 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 60.00000000000001kOhm
# R2 n2 n3 39.99999999999999kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:23,235 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-08 14:15:23,244 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Warning: Model issue on line 11 :'
# 2020-11-08 14:15:23,245 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout .model bc846b npn(is=1.82e-14 nf=0.9932 ise=2.89e-16 ne=1.4 bf=324.4 ikf ...'
# 2020-11-08 14:15:23,247 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (vceo) - ignored'
# 2020-11-08 14:15:23,248 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (icrating) - ignored'
# 2020-11-08 14:15:23,252 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-08 14:15:23,253 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-08 14:15:23,259 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-08 14:15:23,262 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-08 14:15:23,267 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-08 14:15:23,268 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-08 14:15:23,269 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad2_                               0'
# 2020-11-08 14:15:23,270 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_01                                        0'
# 2020-11-08 14:15:23,276 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad2_                               3'
# 2020-11-08 14:15:23,279 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_02                                        5'
# 2020-11-08 14:15:23,281 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q9-pad3_                         -14.9997'
# 2020-11-08 14:15:23,284 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout -15v                                       -15'
# 2020-11-08 14:15:23,285 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q10-pad3_                        -14.9997'
# 2020-11-08 14:15:23,287 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q11-pad2_                        -14.9997'
# 2020-11-08 14:15:23,292 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +15v                                        15'
# 2020-11-08 14:15:23,295 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad1_                        -14.6531'
# 2020-11-08 14:15:23,300 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad1_                        -14.6531'
# 2020-11-08 14:15:23,301 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad2_                             -15'
# 2020-11-08 14:15:23,303 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad1_                         7.04708'
# 2020-11-08 14:15:23,304 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout /mixer_in                              6.33732'
# 2020-11-08 14:15:23,309 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v4#branch                               -5e-05'
# 2020-11-08 14:15:23,311 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v3#branch                                    0'
# 2020-11-08 14:15:23,317 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                            0.0142249'
# 2020-11-08 14:15:23,318 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                           -0.0142954'
# 2020-11-08 14:15:25,283 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00001e-01\r'
# 2020-11-08 14:15:25,490 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10001'
# 2020-11-08 14:15:25,491 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-08 14:15:25,493 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']
# Voltages: Max: 7.084749, Min: 6.114192, p2p: 0.970556, Average: 6.350267
# 2020-11-08 14:15:25,504 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 70.0kOhm
# R2 n2 n3 29.999999999999993kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:25,509 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-08 14:15:25,513 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# ...
# 2020-11-08 14:15:25,553 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad2_                             3.5'
# 2020-11-08 14:15:25,555 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_02                                        5'
# 2020-11-08 14:15:25,558 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q9-pad3_                         -14.9997'
# 2020-11-08 14:15:25,561 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout -15v                                       -15'
# 2020-11-08 14:15:25,563 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q10-pad3_                        -14.9997'
# 2020-11-08 14:15:25,568 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q11-pad2_                        -14.9997'
# 2020-11-08 14:15:25,570 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +15v                                        15'
# 2020-11-08 14:15:25,578 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad1_                        -14.6531'
# 2020-11-08 14:15:25,579 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad1_                        -14.6531'
# 2020-11-08 14:15:25,582 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad2_                             -15'
# 2020-11-08 14:15:25,589 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad1_                         7.04708'
# 2020-11-08 14:15:25,591 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout /mixer_in                              6.33732'
# 2020-11-08 14:15:25,594 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v4#branch                               -5e-05'
# 2020-11-08 14:15:25,595 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v3#branch                                    0'
# 2020-11-08 14:15:25,597 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                            0.0142249'
# 2020-11-08 14:15:25,601 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                           -0.0142954'
# 2020-11-08 14:15:27,641 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00001e-01\r'
# 2020-11-08 14:15:27,841 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10001'
# 2020-11-08 14:15:27,843 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-08 14:15:27,844 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']
# Voltages: Max: 7.281604, Min: 6.038917, p2p: 1.242687, Average: 6.354579
# 2020-11-08 14:15:27,854 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 80.0kOhm
# R2 n2 n3 19.999999999999996kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:27,855 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-08 14:15:27,857 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 80.0kOhm
# R2 n2 n3 19.999999999999996kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:27,859 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-08 14:15:27,861 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Warning: Model issue on line 11 :'
# 2020-11-08 14:15:27,864 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout .model bc846b npn(is=1.82e-14 nf=0.9932 ise=2.89e-16 ne=1.4 bf=324.4 ikf ...'
# 2020-11-08 14:15:27,865 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (vceo) - ignored'
# 2020-11-08 14:15:27,868 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (icrating) - ignored'
# 2020-11-08 14:15:27,872 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-08 14:15:27,878 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-08 14:15:27,881 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-08 14:15:27,884 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-08 14:15:27,885 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-08 14:15:27,887 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-08 14:15:27,891 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad2_                               0'
# 2020-11-08 14:15:27,893 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_01                                        0'
# 2020-11-08 14:15:27,895 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad2_                               4'
# 2020-11-08 14:15:27,897 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_02                                        5'
# 2020-11-08 14:15:27,899 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q9-pad3_                         -14.9997'
# 2020-11-08 14:15:27,901 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout -15v                                       -15'
# 2020-11-08 14:15:27,903 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q10-pad3_                        -14.9997'
# 2020-11-08 14:15:27,905 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q11-pad2_                        -14.9997'
# 2020-11-08 14:15:27,911 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +15v                                        15'
# 2020-11-08 14:15:27,916 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad1_                        -14.6531'
# 2020-11-08 14:15:27,918 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad1_                        -14.6531'
# 2020-11-08 14:15:27,919 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad2_                             -15'
# 2020-11-08 14:15:27,920 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad1_                         7.04708'
# 2020-11-08 14:15:27,925 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout /mixer_in                              6.33732'
# 2020-11-08 14:15:27,928 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v4#branch                               -5e-05'
# 2020-11-08 14:15:27,929 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v3#branch                                    0'
# 2020-11-08 14:15:27,933 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                            0.0142249'
# 2020-11-08 14:15:27,935 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                           -0.0142954'
# 2020-11-08 14:15:29,741 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00000e-01\r'
# 2020-11-08 14:15:29,984 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10001'
# 2020-11-08 14:15:29,985 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-08 14:15:29,987 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']
# Voltages: Max: 7.478455, Min: 5.961516, p2p: 1.516939, Average: 6.358970
# 2020-11-08 14:15:29,993 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 90.0kOhm
# R2 n2 n3 9.999999999999998kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:29,997 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-08 14:15:30,001 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 90.0kOhm
# R2 n2 n3 9.999999999999998kOhm
# .ends voltage_divider
# XRV1 GND Net-_C13-Pad2_ NC_01 voltage_divider
# XRV2 GND Net-_C14-Pad2_ NC_02 voltage_divider
# R28 Net-_Q9-Pad3_ -15V 22k
# R29 Net-_Q10-Pad3_ -15V 22k
# R31 Net-_Q11-Pad2_ Net-_Q10-Pad3_ 47k
# R30 Net-_Q11-Pad2_ Net-_Q9-Pad3_ 47k
# Q9 +15V Net-_C13-Pad1_ Net-_Q9-Pad3_ BC846B
# Q10 +15V Net-_C14-Pad1_ Net-_Q10-Pad3_ BC846B
# R32 Net-_C15-Pad2_ -15V 1.5k
# Q11 +15V Net-_Q11-Pad2_ Net-_C15-Pad2_ BC846B
# C13 Net-_C13-Pad1_ Net-_C13-Pad2_ 1u
# C14 Net-_C14-Pad1_ Net-_C14-Pad2_ 1u
# R33 Net-_C15-Pad1_ +15V 68k
# R34 GND Net-_C15-Pad1_ 100k
# C15 Net-_C15-Pad1_ Net-_C15-Pad2_ 1u
# R35 /MIXER_IN -15V 1.5k
# Q12 +15V Net-_C15-Pad1_ /MIXER_IN BC846B
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 NC_01 0 DC 0V AC 2V SIN(0 5V 1k)
# V4 NC_02 0 DC 0V AC 2V SIN(0 5V 1k 0 0 90)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:30,003 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-08 14:15:30,010 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Warning: Model issue on line 11 :'
# 2020-11-08 14:15:30,011 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout .model bc846b npn(is=1.82e-14 nf=0.9932 ise=2.89e-16 ne=1.4 bf=324.4 ikf ...'
# 2020-11-08 14:15:30,012 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (vceo) - ignored'
# 2020-11-08 14:15:30,013 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (icrating) - ignored'
# 2020-11-08 14:15:30,016 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-08 14:15:30,022 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-08 14:15:30,025 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-08 14:15:30,029 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-08 14:15:30,030 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-08 14:15:30,032 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-08 14:15:30,034 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad2_                               0'
# 2020-11-08 14:15:30,035 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_01                                        0'
# 2020-11-08 14:15:30,036 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad2_                             4.5'
# 2020-11-08 14:15:30,037 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_02                                        5'
# 2020-11-08 14:15:30,045 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q9-pad3_                         -14.9997'
# 2020-11-08 14:15:30,046 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout -15v                                       -15'
# 2020-11-08 14:15:30,049 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q10-pad3_                        -14.9997'
# 2020-11-08 14:15:30,057 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q11-pad2_                        -14.9997'
# 2020-11-08 14:15:30,058 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +15v                                        15'
# 2020-11-08 14:15:30,060 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c13-pad1_                        -14.6531'
# 2020-11-08 14:15:30,062 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c14-pad1_                        -14.6531'
# 2020-11-08 14:15:30,066 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad2_                             -15'
# 2020-11-08 14:15:30,068 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c15-pad1_                         7.04708'
# 2020-11-08 14:15:30,071 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout /mixer_in                              6.33732'
# 2020-11-08 14:15:30,074 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v4#branch                               -5e-05'
# 2020-11-08 14:15:30,075 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v3#branch                                    0'
# 2020-11-08 14:15:30,078 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                            0.0142249'
# 2020-11-08 14:15:30,080 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                           -0.0142954'
# 2020-11-08 14:15:32,134 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00000e-01\r'
# 2020-11-08 14:15:32,337 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10001'
# 2020-11-08 14:15:32,338 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-08 14:15:32,339 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']
# Voltages: Max: 7.675611, Min: 5.882516, p2p: 1.793095, Average: 6.363407

# %% [markdown]
# ### filter sections

# %%
#load the diffpair schema
kicad_netlist_path = directory_path.joinpath('main', 'Low Pass 200.cir')
parser = SpiceParser(path=str(kicad_netlist_path))

# %%
#simulate fuzz with a sine wave
lp = parser.build_circuit(ground=5)
lp.include(spice_library['BC846B'])
lp.include(spice_library['BC556B'])
lp.V('1', '+15V', lp.gnd, 'DC 15')
lp.V('2', 'NC_01', lp.gnd, 'DC 0V AC 2V SIN(6 2V 50)')

simulator = lp.simulator(temperature=25, nominal_temperature=25)
analysis_lp = simulator.transient(step_time=1@u_us, start_time=10@u_ms, end_time=100@u_ms)
# Out:
# 2020-11-08 14:15:32,419 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# C11 Net-_C11-Pad1_ GND 22n
# C12 Net-_C1-Pad1_ Net-_C12-Pad2_ 22n
# R24 Net-_C12-Pad2_ NC_01 15k
# R25 Net-_C11-Pad1_ Net-_C12-Pad2_ 15k
# Q1 Net-_Q1-Pad1_ Net-_Q1-Pad2_ Net-_C1-Pad1_ BC846B
# Q2 Net-_C1-Pad1_ Net-_Q1-Pad1_ +15V BC556B
# R1 Net-_Q1-Pad2_ Net-_C11-Pad1_ 10k
# R2 GND Net-_C1-Pad1_ 1.5k
# R3 /OUT GND 10k
# C1 Net-_C1-Pad1_ /OUT 100u
# V1 +15V 0 DC 15
# V2 NC_01 0 DC 0V AC 2V SIN(6 2V 50)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 100ms 10ms
# .end
#
# 2020-11-08 14:15:32,420 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-08 14:15:32,423 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# C11 Net-_C11-Pad1_ GND 22n
# C12 Net-_C1-Pad1_ Net-_C12-Pad2_ 22n
# R24 Net-_C12-Pad2_ NC_01 15k
# R25 Net-_C11-Pad1_ Net-_C12-Pad2_ 15k
# Q1 Net-_Q1-Pad1_ Net-_Q1-Pad2_ Net-_C1-Pad1_ BC846B
# Q2 Net-_C1-Pad1_ Net-_Q1-Pad1_ +15V BC556B
# R1 Net-_Q1-Pad2_ Net-_C11-Pad1_ 10k
# R2 GND Net-_C1-Pad1_ 1.5k
# R3 /OUT GND 10k
# C1 Net-_C1-Pad1_ /OUT 100u
# V1 +15V 0 DC 15
# V2 NC_01 0 DC 0V AC 2V SIN(6 2V 50)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 100ms 10ms
# .end
#
# 2020-11-08 14:15:32,426 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-08 14:15:32,429 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Warning: Model issue on line 11 :'
# 2020-11-08 14:15:32,434 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout .model bc846b npn(is=1.82e-14 nf=0.9932 ise=2.89e-16 ne=1.4 bf=324.4 ikf ...'
# 2020-11-08 14:15:32,438 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (vceo) - ignored'
# 2020-11-08 14:15:32,440 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (icrating) - ignored'
# 2020-11-08 14:15:32,441 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Warning: Model issue on line 12 :'
# 2020-11-08 14:15:32,442 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout .model bc556b pnp(is=3.83e-14 nf=1.008 ise=1.22e-14 ne=1.528 bf=344.4 ik ...'
# 2020-11-08 14:15:32,444 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (vceo) - ignored'
# 2020-11-08 14:15:32,446 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (icrating) - ignored'
# 2020-11-08 14:15:32,451 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-08 14:15:32,453 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-08 14:15:32,456 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-08 14:15:32,458 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-08 14:15:32,459 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-08 14:15:32,460 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-08 14:15:32,461 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c11-pad1_                          5.9993'
# 2020-11-08 14:15:32,464 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c1-pad1_                          5.49301'
# 2020-11-08 14:15:32,467 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c12-pad2_                         5.99965'
# 2020-11-08 14:15:32,469 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_01                                        6'
# 2020-11-08 14:15:32,472 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q1-pad1_                          14.3509'
# 2020-11-08 14:15:32,473 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_q1-pad2_                          5.99907'
# 2020-11-08 14:15:32,474 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +15v                                        15'
# 2020-11-08 14:15:32,476 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout /out                                         0'
# 2020-11-08 14:15:32,477 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                         -2.33355e-08'
# 2020-11-08 14:15:32,479 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                          -0.00366199'
# 2020-11-08 14:15:32,629 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00003e-02\r'
# 2020-11-08 14:15:32,876 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  2.58733e-02\r'
# 2020-11-08 14:15:33,126 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  4.18913e-02\r'
# 2020-11-08 14:15:33,375 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  5.89913e-02\r'
# 2020-11-08 14:15:33,625 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  7.49563e-02\r'
# 2020-11-08 14:15:33,874 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  8.84933e-02\r'
# 2020-11-08 14:15:34,059 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 90001'
# 2020-11-08 14:15:34,060 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-08 14:15:34,063 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']

# %%
#plot the results
#fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, sharex=False, figsize=(18, 6))
fig, ax0 = plt.subplots(figsize=(18, 6))

#plot the image
#img_diffpair_path = directory_path.joinpath('diffpair', 'diffpair.png')
#img_diffpair = mpimg.imread(str(img_diffpair_path))
#im = ax0.imshow(img_diffpair)
#ax0.axis('off')
#ax0.set_title('long tailed pair differential amplifier', y=-0.2)
        
#plot with envelope
ax0.plot(analysis_lp['NC_01'].abscissa*1000, analysis_lp['NC_01'], c='grey')  # envelope input (scaled)
ax0.plot(analysis_lp['/OUT'].abscissa*1000, analysis_lp['/OUT'], c='orange')  # differential output
ax0.plot(analysis_lp['Net-_C1-Pad1_'].abscissa*1000, analysis_lp['Net-_C1-Pad1_'], c='green')  # differential output
ax0.grid()
ax0.set_xlabel('t [ms]')
ax0.set_ylabel('[V]')
ax0.set_title('low pass filter [200Hz]', y=-0.2)

#plot with envelope
#ax2.plot(analysis_fuzz_square['IN'].abscissa*1000, analysis_fuzz_square['IN'], c='grey')  # envelope input (scaled)
#ax2.plot(analysis_fuzz_square['OUT'].abscissa*1000, analysis_fuzz_square['OUT'], c='orange')  # differential output
#ax2.grid()
#ax2.set_xlabel('t [ms]')
#ax2.set_ylabel('[V]')
#ax2.set_title('output with a cv envelope', y=-0.2)

plt.show()
# Out:
# 2020-11-08 14:15:34,155 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'multiply'> is NEW_UNIT
# 2020-11-08 14:15:34,164 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'multiply'> is NEW_UNIT
# 2020-11-08 14:15:34,173 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'multiply'> is NEW_UNIT

# %%
analysis_ac_lp = simulator.ac(start_frequency=10@u_Hz, stop_frequency=1@u_kHz, number_of_points=10,  variation='dec')
# Out:
# 2020-11-08 14:15:34,527 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# C11 Net-_C11-Pad1_ GND 22n
# C12 Net-_C1-Pad1_ Net-_C12-Pad2_ 22n
# R24 Net-_C12-Pad2_ NC_01 15k
# R25 Net-_C11-Pad1_ Net-_C12-Pad2_ 15k
# Q1 Net-_Q1-Pad1_ Net-_Q1-Pad2_ Net-_C1-Pad1_ BC846B
# Q2 Net-_C1-Pad1_ Net-_Q1-Pad1_ +15V BC556B
# R1 Net-_Q1-Pad2_ Net-_C11-Pad1_ 10k
# R2 GND Net-_C1-Pad1_ 1.5k
# R3 /OUT GND 10k
# C1 Net-_C1-Pad1_ /OUT 100u
# V1 +15V 0 DC 15
# V2 NC_01 0 DC 0V AC 2V SIN(6 2V 50)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .ac dec 10 10Hz 1kHz
# .end
#
# 2020-11-08 14:15:34,530 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-08 14:15:34,535 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/bc5x7.lib
# C11 Net-_C11-Pad1_ GND 22n
# C12 Net-_C1-Pad1_ Net-_C12-Pad2_ 22n
# R24 Net-_C12-Pad2_ NC_01 15k
# R25 Net-_C11-Pad1_ Net-_C12-Pad2_ 15k
# Q1 Net-_Q1-Pad1_ Net-_Q1-Pad2_ Net-_C1-Pad1_ BC846B
# Q2 Net-_C1-Pad1_ Net-_Q1-Pad1_ +15V BC556B
# R1 Net-_Q1-Pad2_ Net-_C11-Pad1_ 10k
# R2 GND Net-_C1-Pad1_ 1.5k
# R3 /OUT GND 10k
# C1 Net-_C1-Pad1_ /OUT 100u
# V1 +15V 0 DC 15
# V2 NC_01 0 DC 0V AC 2V SIN(6 2V 50)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .ac dec 10 10Hz 1kHz
# .end
#
# 2020-11-08 14:15:34,540 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-08 14:15:34,547 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Warning: Model issue on line 11 :'
# 2020-11-08 14:15:34,549 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout .model bc846b npn(is=1.82e-14 nf=0.9932 ise=2.89e-16 ne=1.4 bf=324.4 ikf ...'
# 2020-11-08 14:15:34,551 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (vceo) - ignored'
# 2020-11-08 14:15:34,553 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (icrating) - ignored'
# 2020-11-08 14:15:34,554 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Warning: Model issue on line 12 :'
# 2020-11-08 14:15:34,557 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout .model bc556b pnp(is=3.83e-14 nf=1.008 ise=1.22e-14 ne=1.528 bf=344.4 ik ...'
# 2020-11-08 14:15:34,558 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (vceo) - ignored'
# 2020-11-08 14:15:34,559 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout unrecognized parameter (icrating) - ignored'
# 2020-11-08 14:15:34,560 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-08 14:15:34,565 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-08 14:15:34,567 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00000e+01\r'
# 2020-11-08 14:15:34,569 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 21'
# 2020-11-08 14:15:34,570 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-08 14:15:34,572 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['ac1', 'const']

# %%
R1 = 15@u_kOhm
R2 = 15@u_kOhm
C1 = 220@u_nF 
C2 = 22@u_nF
resonant_frequency = 1 / (2 * math.pi * math.sqrt(R1 * R2 * C1 * C2 ))
print( resonant_frequency )
# Out:
# 152.512763952991

# %%
figure, axes = plt.subplots(2, figsize=(20, 10))
plt.title("Bode Diagrams of RLC Filters")
out = 'Net-_C1-Pad1_'
bode_diagram(axes=axes,
                 frequency=analysis_ac_lp.frequency,
                 gain=-2.4*np.log10(np.absolute(analysis_ac_lp[out])),
                 phase=np.angle(analysis_ac_lp[out], deg=False),
                 marker='.',
                 color='blue',
                 linestyle='-',
    )
for axe in axes:
    axe.axvline(x=resonant_frequency, color='red')
# Out:
# 2020-11-08 14:16:38,318 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'absolute'> is NO_CONVERSION
# 2020-11-08 14:16:38,322 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'log10'> is FLOAT
# 2020-11-08 14:16:38,324 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - WARNING - Should be unit less
# 2020-11-08 14:16:38,329 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'arctan2'> is FLOAT
# 2020-11-08 14:16:38,331 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - WARNING - Should be unit less

# %%
#simulate fuzz with a sine wave
fuzz = parser.build_circuit(ground=5)
fuzz.include(spice_library['BC547B'])
fuzz.V('1', '+15V', fuzz.gnd, 'DC 15')
fuzz.V('3', 'IN', fuzz.gnd, 'DC 0V AC 0V PULSE(-0.5V +0.5V 0 0 0 2m 4m)')

class VoltageDivider(SubCircuitFactory):
    __name__ = 'voltage_divider'
    __nodes__ = ('n1', 'n2', 'n3' )
    def __init__(self, R=100@u_kΩ, w=0.4):
        super().__init__()
        self.R(1, 'n1', 'n2', R * w)
        self.R(2, 'n2', 'n3', R * (1.0-w) )

fuzz.subcircuit(VoltageDivider(R=100@u_kΩ, w=0.5))

simulator = fuzz.simulator(temperature=25, nominal_temperature=25)
analysis_fuzz_square = simulator.transient(step_time=1@u_us, start_time=100@u_ms, end_time=110@u_ms)
# Out:
# 2020-11-08 14:15:36,425 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/BC547.mod
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 50.0kOhm
# R2 n2 n3 50.0kOhm
# .ends voltage_divider
# C11 Net-_C11-Pad1_ GND 22n
# C12 Net-_C1-Pad1_ Net-_C12-Pad2_ 22n
# R24 Net-_C12-Pad2_ NC_01 15k
# R25 Net-_C11-Pad1_ Net-_C12-Pad2_ 15k
# Q1 Net-_Q1-Pad1_ Net-_Q1-Pad2_ Net-_C1-Pad1_ BC846B
# Q2 Net-_C1-Pad1_ Net-_Q1-Pad1_ +15V BC556B
# R1 Net-_Q1-Pad2_ Net-_C11-Pad1_ 10k
# R2 GND Net-_C1-Pad1_ 1.5k
# R3 /OUT GND 10k
# C1 Net-_C1-Pad1_ /OUT 100u
# V1 +15V 0 DC 15
# V3 IN 0 DC 0V AC 0V PULSE(-0.5V +0.5V 0 0 0 2m 4m)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:36,430 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-08 14:15:36,433 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/BC547.mod
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 50.0kOhm
# R2 n2 n3 50.0kOhm
# .ends voltage_divider
# C11 Net-_C11-Pad1_ GND 22n
# C12 Net-_C1-Pad1_ Net-_C12-Pad2_ 22n
# R24 Net-_C12-Pad2_ NC_01 15k
# R25 Net-_C11-Pad1_ Net-_C12-Pad2_ 15k
# Q1 Net-_Q1-Pad1_ Net-_Q1-Pad2_ Net-_C1-Pad1_ BC846B
# Q2 Net-_C1-Pad1_ Net-_Q1-Pad1_ +15V BC556B
# R1 Net-_Q1-Pad2_ Net-_C11-Pad1_ 10k
# R2 GND Net-_C1-Pad1_ 1.5k
# R3 /OUT GND 10k
# C1 Net-_C1-Pad1_ /OUT 100u
# V1 +15V 0 DC 15
# V3 IN 0 DC 0V AC 0V PULSE(-0.5V +0.5V 0 0 0 2m 4m)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-08 14:15:36,435 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b"stderr warning, can't find model bc846b"
# 2020-11-08 14:15:36,437 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - warning, can't find model bc846b
# 2020-11-08 14:15:36,442 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b"stderr warning, can't find model bc556b"
# 2020-11-08 14:15:36,444 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - warning, can't find model bc556b
# 2020-11-08 14:15:36,446 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-08 14:15:36,448 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Error on line 11 :'
# 2020-11-08 14:15:36,451 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout q1 net-_q1-pad1_ net-_q1-pad2_ net-_c1-pad1_ bc846b'
# 2020-11-08 14:15:36,452 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout could not find a valid modelname'
# 2020-11-08 14:15:36,454 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Error on line 12 :'
# 2020-11-08 14:15:36,457 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout q2 net-_c1-pad1_ net-_q1-pad1_ +15v bc556b'
# 2020-11-08 14:15:36,460 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout could not find a valid modelname'
# 2020-11-08 14:15:36,461 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - ERROR -
# Circuit: KiCad schematic
# Error on line 11 :
# q1 net-_q1-pad1_ net-_q1-pad2_ net-_c1-pad1_ bc846b
# could not find a valid modelname
# Error on line 12 :
# q2 net-_c1-pad1_ net-_q1-pad1_ +15v bc556b
# could not find a valid modelname
# ---------------------------------------------------------------------------
# NgSpiceCircuitError                       Traceback (most recent call last)
# <ipython-input-11-21d2c8f63d68> in <module>
#      16
#      17 simulator = fuzz.simulator(temperature=25, nominal_temperature=25)
# ---> 18 analysis_fuzz_square = simulator.transient(step_time=1@u_us, start_time=100@u_ms, end_time=110@u_ms)
#
# /usr/local/lib/python3.8/dist-packages/PySpice/Spice/Simulation.py in transient(self, *args, **kwargs)
#    1164
#    1165     def transient(self, *args, **kwargs):
# -> 1166         return self._run('transient', *args, **kwargs)
#    1167
#    1168     ##############################################
#
# /usr/local/lib/python3.8/dist-packages/PySpice/Spice/NgSpice/Simulation.py in _run(self, analysis_method, *args, **kwargs)
#     115         self._ngspice_shared.destroy()
#     116         # Fixme: Error: circuit not parsed.
# --> 117         self._ngspice_shared.load_circuit(str(self))
#     118         self._ngspice_shared.run()
#     119         self._logger.debug(str(self._ngspice_shared.plot_names))
#
# /usr/local/lib/python3.8/dist-packages/PySpice/Spice/NgSpice/Shared.py in load_circuit(self, circuit)
#    1144         if self._error_in_stdout:
#    1145             self._logger.error('\n' + self.stdout)
# -> 1146             raise NgSpiceCircuitError('')
#    1147
#    1148         # for line in circuit_lines:
#
# NgSpiceCircuitError:

# %%
#plot the results
fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, sharex=False, figsize=(18, 6))

#plot the image
#img_diffpair_path = directory_path.joinpath('diffpair', 'diffpair.png')
#img_diffpair = mpimg.imread(str(img_diffpair_path))
#im = ax0.imshow(img_diffpair)
#ax0.axis('off')
#ax0.set_title('long tailed pair differential amplifier', y=-0.2)
        
#plot with envelope
ax1.plot(analysis_fuzz_sine['IN'].abscissa*1000, analysis_fuzz_sine['IN'], c='grey')  # envelope input (scaled)
ax1.plot(analysis_fuzz_sine['OUT'].abscissa*1000, analysis_fuzz_sine['OUT'], c='orange')  # differential output
ax1.grid()
ax1.set_xlabel('t [ms]')
ax1.set_ylabel('[V]')
ax1.set_title('output with a cv envelope', y=-0.2)

#plot with envelope
ax2.plot(analysis_fuzz_square['IN'].abscissa*1000, analysis_fuzz_square['IN'], c='grey')  # envelope input (scaled)
ax2.plot(analysis_fuzz_square['OUT'].abscissa*1000, analysis_fuzz_square['OUT'], c='orange')  # differential output
ax2.grid()
ax2.set_xlabel('t [ms]')
ax2.set_ylabel('[V]')
ax2.set_title('output with a cv envelope', y=-0.2)

plt.show()

# %% [markdown]
# more promising is it to use a four quadrant multiplier, also known as gilbert cell. the gilbert cell is designed around two differential amplifiers. the carrier signal switches between those. the result is a multiplication of the input voltages. the gilbert cell is mostly used for amplitude modulation in radio transmission. if you look at the integratd circuits like the 633 it can modulate signals up in the gigahertz range. the gilbert cell is not described in all details here, there is a good introduction from w2aew [[4][4]].

# %% [markdown]
# this is not real amplitude modulation. when the signal is negative the phase of the output is inverted. this can be adjusted by the bias voltage of the control voltage. the control voltage has to be positive at all time.

# %% [markdown]
# ## *construction*
#
# for the final circuit input and output buffering and biasing is needed. the buffering is done with opamps.

# %% [markdown]
# first we design the input stage. the input voltage for the X signal should be 10mV and 20mV for the control voltage.

# %% [markdown]
# ## *references*
#
# - [VCA Techniques Investigated][1] Rod Elliott (ESP)
# - [Popular Electronics][2] Keyiing and VCA citcuits for electronic music instruments
# - [VCA-1][3] Thomas Henry CA3080 vca
# - [VCA-3][4] René Schmitz differential pair vca
# - [#223][5]: Basics of the Gilbert Cell | Analog Multiplier | Mixer | Modulator
# - [#224][6]: AM & DSB-SC Modulation with the Gilbert Cell
# - [Analog Devices][8]: Analog multiplier application guide
# - [AD633][9]: Datasheet
#
#
#
#
# [1]: https://static1.squarespace.com/static/5e6e99e8bd2f8a6de8454feb/t/5e77db16e8ff44374c24b124/1584913176675/MBD+BOM+and+build.pdf
# [2]: https://www.diystompboxes.com/smfforum/index.php?topic=118397.0
# [3]: https://www.diystompboxes.com/smfforum/index.php?topic=99779.0
