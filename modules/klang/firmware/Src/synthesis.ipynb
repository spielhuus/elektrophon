# %% [markdown]
# # synthesis calculations and notes

# %% [markdown]
# calculating frequencies from midi notes:

# %%
import numpy as np
import matplotlib.pyplot as plot

# %%
a = 11
b = 10
print( "result %d" %(a+b))
# Out:
# result 21

# %% [markdown]
# calculate sine wave with cmsis dsp.

# %%
x =  x = np.linspace(-np.pi, np.pi, 1024)
#data = {}
#counter = 0;
#for i in x :
#    #print( "value: %f" %(numpy.sin(i)))
#    data[counter] = i
#    counter += 1

data = np.sin(x)
plot.plot(x, (data+1.0)*2000.0)
plot.title('sine') 
plot.xlabel('Time')
plot.ylabel('Amplitude = sin(time)')
plot.grid(True, which='both')
plot.axhline(y=0, color='k')
plot.show()

# %% [markdown]
# ## calculate frequency
#
# calculate the playback frequency:
# <img src="http://latex.codecogs.com/gif.latex?f%20%3D%20%5Cfrac%7B1%7D%7Bt_%7Bint%7D*size_%7Btable%7D%7D"/><br/>
#
# for increment = 1:

# %%
frequency = 1000000
steps = 1024
increment = 0.1

print("1/((1/40000)*1024) = %f Hz" %(1/((1/frequency)*(steps/increment))))
# Out:
# 1/((1/40000)*1024) = 97.656250 Hz

# %%
def writeArray(table = [], name="wavetable"):   
  print("\nfloat32_t %s[%d] = {\n\t" %(name,len(table)), end='')
  rows = 0
  for i in range(1,len(table)):
    if rows > 10 :
      rows = 0
      print("\n\t", end='')
    print("%f, " %(table[i]), end = '')
    rows = rows + 1
  print("\n};")

print("/* autogenerated wavetables */")
print("#include \"wavetable.h\"")

x = np.linspace(-np.pi, np.pi, 1024)
data = np.sin(x)
plot.plot(x, (data))
writeArray((data), "wt_sine")
# Out:
# /* autogenerated wavetables */
# #include "wavetable.h"
#
# float32_t wt_sine[1024] = {
# 	-0.006142, -0.012284, -0.018425, -0.024565, -0.030705, -0.036843, -0.042980, -0.049116, -0.055249, -0.061381, -0.067510,
# 	-0.073636, -0.079760, -0.085881, -0.091999, -0.098113, -0.104223, -0.110330, -0.116432, -0.122530, -0.128623, -0.134711,
# 	-0.140795, -0.146873, -0.152945, -0.159012, -0.165073, -0.171127, -0.177175, -0.183217, -0.189251, -0.195279, -0.201299,
# 	-0.207311, -0.213315, -0.219312, -0.225300, -0.231280, -0.237251, -0.243213, -0.249166, -0.255109, -0.261043, -0.266967,
# 	-0.272881, -0.278785, -0.284678, -0.290560, -0.296432, -0.302292, -0.308141, -0.313978, -0.319803, -0.325617, -0.331418,
# 	-0.337206, -0.342982, -0.348745, -0.354494, -0.360231, -0.365954, -0.371662, -0.377357, -0.383038, -0.388704, -0.394356,
# 	-0.399993, -0.405614, -0.411220, -0.416811, -0.422386, -0.427945, -0.433488, -0.439015, -0.444525, -0.450018, -0.455495,
# ...

# %%
def writeArray(table = [], name="wavetable"):   
  print("\nfloat32_t %s[%d] = {\n\t" %(name,len(table)), end='')
  rows = 0
  for i in range(1,len(table)):
    if rows > 10 :
      rows = 0
      print("\n\t", end='')
    print("%f, " %(table[i]), end = '')
    rows = rows + 1
  print("\n};")

print("/* autogenerated wavetables */")
print("#include \"wavetable.h\"")

x = np.linspace(-np.pi, np.pi, 1024)
data = np.sin(x)
plot.plot(x, (((data*1.2)+1)*2040))
#writeArray((data), "wt_sine")
# Out:
# /* autogenerated wavetables */
# #include "wavetable.h"
