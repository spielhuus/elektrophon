# %%
# Just the normal prequisites for using matplotlib and numpy in a Jupyter notebook
# %matplotlib inline
# Use the svg backend, in my opinion it just makes better looking plots
# %config InlineBackend.figure_format = 'svg'

import PySpice.Logging.Logging as Logging
logger = Logging.setup_logging( logging_level='DEBUG')

import os
import sys
import IPython
from scipy import signal
import scipy.fftpack
from PySpice.Unit import *
from PySpice.Spice.Parser import SpiceParser
from PySpice.Spice.Netlist import Circuit, SubCircuit, SubCircuitFactory
from PySpice.Spice.Library import SpiceLibrary
from PySpice.Probe.Plot import plot
from PySpice.Doc.ExampleTools import find_libraries
from PySpice.Math import *
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt
import unittest

sys.path.append('../../../lib/python')
import Spice2Wav.Spice2Wav as wav

import PySpice.Logging.Logging as Logging
logger = Logging.setup_logging()

directory_path = Path(os.path.abspath('')).resolve().parent.parent.parent
spice_libraries_path = directory_path.joinpath("lib", "spice")
spice_library = SpiceLibrary(spice_libraries_path)

directory_path = Path(os.path.abspath('')).resolve()
# Out:
# 2020-11-02 18:03:30,389 - PySpice.Spice.Netlist.__new__ - DEBUG - Element don't define a __pins__ attribute
# 2020-11-02 18:03:30,390 - PySpice.Spice.Netlist.__new__ - DEBUG - FixedPinElement don't define a __pins__ attribute
# 2020-11-02 18:03:30,393 - PySpice.Spice.Netlist.__new__ - DEBUG - SubCircuitElement don't define a __pins__ attribute
# 2020-11-02 18:03:30,396 - PySpice.Spice.Netlist.__new__ - DEBUG - Resistor don't define a __pins__ attribute
# 2020-11-02 18:03:30,399 - PySpice.Spice.Netlist.__new__ - DEBUG - SemiconductorResistor don't define a __pins__ attribute
# 2020-11-02 18:03:30,402 - PySpice.Spice.Netlist.__new__ - DEBUG - BehavioralResistor don't define a __pins__ attribute
# 2020-11-02 18:03:30,404 - PySpice.Spice.Netlist.__new__ - DEBUG - Capacitor don't define a __pins__ attribute
# 2020-11-02 18:03:30,409 - PySpice.Spice.Netlist.__new__ - DEBUG - SemiconductorCapacitor don't define a __pins__ attribute
# 2020-11-02 18:03:30,414 - PySpice.Spice.Netlist.__new__ - DEBUG - BehavioralCapacitor don't define a __pins__ attribute
# 2020-11-02 18:03:30,418 - PySpice.Spice.Netlist.__new__ - DEBUG - Inductor don't define a __pins__ attribute
# 2020-11-02 18:03:30,419 - PySpice.Spice.Netlist.__new__ - DEBUG - BehavioralInductor don't define a __pins__ attribute
# 2020-11-02 18:03:30,420 - PySpice.Spice.Netlist.__new__ - DEBUG - CoupledInductor don't define a __pins__ attribute
# 2020-11-02 18:03:30,421 - PySpice.Spice.Netlist.__new__ - DEBUG - VoltageControlledSwitch don't define a __pins__ attribute
# 2020-11-02 18:03:30,423 - PySpice.Spice.Netlist.__new__ - DEBUG - CurrentControlledSwitch don't define a __pins__ attribute
# 2020-11-02 18:03:30,431 - PySpice.Spice.Netlist.__new__ - DEBUG - VoltageSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,434 - PySpice.Spice.Netlist.__new__ - DEBUG - CurrentSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,437 - PySpice.Spice.Netlist.__new__ - DEBUG - VoltageControlledCurrentSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,438 - PySpice.Spice.Netlist.__new__ - DEBUG - VoltageControlledVoltageSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,442 - PySpice.Spice.Netlist.__new__ - DEBUG - CurrentControlledCurrentSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,447 - PySpice.Spice.Netlist.__new__ - DEBUG - CurrentControlledVoltageSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,449 - PySpice.Spice.Netlist.__new__ - DEBUG - BehavioralSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,452 - PySpice.Spice.Netlist.__new__ - DEBUG - NonLinearVoltageSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,454 - PySpice.Spice.Netlist.__new__ - DEBUG - NonLinearCurrentSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,461 - PySpice.Spice.Netlist.__new__ - DEBUG - JunctionFieldEffectTransistor don't define a __pins__ attribute
# 2020-11-02 18:03:30,464 - PySpice.Spice.Netlist.__new__ - DEBUG - Mesfet don't define a __pins__ attribute
# 2020-11-02 18:03:30,470 - PySpice.Spice.Netlist.__new__ - DEBUG - LosslessTransmissionLine don't define a __pins__ attribute
# 2020-11-02 18:03:30,473 - PySpice.Spice.Netlist.__new__ - DEBUG - LossyTransmission don't define a __pins__ attribute
# 2020-11-02 18:03:30,480 - PySpice.Spice.Netlist.__new__ - DEBUG - CoupledMulticonductorLine don't define a __pins__ attribute
# 2020-11-02 18:03:30,483 - PySpice.Spice.Netlist.__new__ - DEBUG - SingleLossyTransmissionLine don't define a __pins__ attribute
# 2020-11-02 18:03:30,485 - PySpice.Spice.Netlist.__new__ - DEBUG - XSpiceElement don't define a __pins__ attribute
# 2020-11-02 18:03:30,488 - PySpice.Spice.Netlist.__new__ - DEBUG - GSSElement don't define a __pins__ attribute
# 2020-11-02 18:03:30,491 - PySpice.Spice.Netlist.__new__ - DEBUG - SinusoidalVoltageSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,493 - PySpice.Spice.Netlist.__new__ - DEBUG - SinusoidalCurrentSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,495 - PySpice.Spice.Netlist.__new__ - DEBUG - AcLine don't define a __pins__ attribute
# 2020-11-02 18:03:30,497 - PySpice.Spice.Netlist.__new__ - DEBUG - PulseVoltageSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,499 - PySpice.Spice.Netlist.__new__ - DEBUG - PulseCurrentSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,501 - PySpice.Spice.Netlist.__new__ - DEBUG - ExponentialVoltageSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,503 - PySpice.Spice.Netlist.__new__ - DEBUG - ExponentialCurrentSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,504 - PySpice.Spice.Netlist.__new__ - DEBUG - PieceWiseLinearVoltageSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,506 - PySpice.Spice.Netlist.__new__ - DEBUG - PieceWiseLinearCurrentSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,510 - PySpice.Spice.Netlist.__new__ - DEBUG - SingleFrequencyFMVoltageSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,512 - PySpice.Spice.Netlist.__new__ - DEBUG - SingleFrequencyFMCurrentSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,514 - PySpice.Spice.Netlist.__new__ - DEBUG - AmplitudeModulatedVoltageSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,516 - PySpice.Spice.Netlist.__new__ - DEBUG - AmplitudeModulatedCurrentSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,519 - PySpice.Spice.Netlist.__new__ - DEBUG - RandomVoltageSource don't define a __pins__ attribute
# 2020-11-02 18:03:30,520 - PySpice.Spice.Netlist.__new__ - DEBUG - RandomCurrentSource don't define a __pins__ attribute

# %% [markdown]
# ![module](https://img.shields.io/badge/module-shin%20ey-yellow) ![status](https://img.shields.io/badge/status-work%20in%20progress-orange)
#
# ## *shin ey*
#
# <a href="https://photos.app.goo.gl/pg6iZUC32rTKX5LC7"><img src="https://spielhuus.github.io/elektrophon/images/kontrast-logo-tmb.jpg" height="300px" align="right"></a>
#
# ***table of contents***
#
# * [*about*](#about)
# * [*construction*](#construction)
# * [*calibration*](#calibration)
# * [*usage*](#usage)
# * [*credits*](#credits)
# * [*links*](#links)
# * [*changelog*](#changelog)
#
# <br/><br/><br/><br/>
#
# ## *about*
#
# pegel is a voltage controlled amplifier (vca). there are various designs to implement a vca. rod elliott (ESP) has an article on vca techniques [[1][1]]. diy synthesizer modules are usualy designed with an integrated vca chip [[2][2]]  or with a differential amplifier [[3][3]]. the integrated vca chips are either obsolete or rather expensive. the differential amplifier can be built with transistors only. the design has some downsides. even in the simulation the result is not symetryc and has a dc offset from the control voltage. this needs a lot of trimming to get an accurate result. but the biggest downside is, that this design can not do proper amplitude modulation (am). when the carrier signal goes below zero the base signal is completely muted.

# %%
#load the diffpair schema
kicad_netlist_path = directory_path.joinpath('Fuzz.cir')
parser = SpiceParser(path=str(kicad_netlist_path))

# %%
#simulate fuzz with a sine wave
fuzz = parser.build_circuit(ground=5)
fuzz.include(spice_library['TL072c'])
fuzz.include(spice_library['D1N4148'])
fuzz.V('1', '+15V', fuzz.gnd, 'DC 15')
fuzz.V('2', '-15V', fuzz.gnd, 'DC -15')
fuzz.V('3', 'IN', fuzz.gnd, 'DC 0V AC 0V SIN(0 0.5V 500)')

class VoltageDivider(SubCircuitFactory):
    __name__ = 'voltage_divider'
    __nodes__ = ('n1', 'n2', 'n3' )
    def __init__(self, R=100@u_kΩ, w=0.4):
        super().__init__()
        self.R(1, 'n1', 'n2', R * w)
        self.R(2, 'n2', 'n3', R * (1.0-w) )

fuzz.subcircuit(VoltageDivider(R=100@u_kΩ, w=0.5))

simulator = fuzz.simulator(temperature=25, nominal_temperature=25)
analysis_fuzz_sine = simulator.transient(step_time=1@u_us, start_time=100@u_ms, end_time=110@u_ms)
# Out:
# 2020-11-02 18:03:30,694 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.new_instance - DEBUG - New instance for id 0
# 2020-11-02 18:03:30,698 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._load_library - DEBUG - Set locale LC_NUMERIC to C
# 2020-11-02 18:03:30,763 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._load_library - DEBUG - Load library libngspice.so
# 2020-11-02 18:03:30,809 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stderr Error: bad type for debug var'
# 2020-11-02 18:03:30,810 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Error: bad type for debug var
# 2020-11-02 18:03:30,814 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stderr Warning: ngspice compiled without debug messages'
# 2020-11-02 18:03:30,818 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - WARNING - Warning: ngspice compiled without debug messages
# 2020-11-02 18:03:30,826 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ******'
# 2020-11-02 18:03:30,829 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** ngspice-31 shared library'
# 2020-11-02 18:03:30,832 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** Creation Date: Sun Oct 27 09:07:06 UTC 2019'
# 2020-11-02 18:03:30,834 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ******'
# 2020-11-02 18:03:30,855 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: version -f
# 2020-11-02 18:03:30,858 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ******'
# 2020-11-02 18:03:30,860 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** ngspice-31 : Circuit level simulation program'
# 2020-11-02 18:03:30,865 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout 
- PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout nc_01                                 -14.4361'
# 2020-11-02 18:03:31,068 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1b.9                                   0'
# 2020-11-02 18:03:31,071 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1b.8                               13.28'
# 2020-11-02 18:03:31,073 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_d4-pad2_                      1.39104e-05'
# 2020-11-02 18:03:31,075 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_d2-pad2_                      1.24405e-05'
# 2020-11-02 18:03:31,081 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_d1-pad1_                      1.24405e-05'
# 2020-11-02 18:03:31,083 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_d3-pad1_                      1.39104e-05'
# 2020-11-02 18:03:31,086 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout h.xu1.h.xu1b.hlim#branch          -2.07744e-16'
# 2020-11-02 18:03:31,089 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v.xu1.v.xu1b.vlim#branch           1.03872e-07'
# 2020-11-02 18:03:31,092 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout h.xu1.h.xu1a.hlim#branch          -9.00956e-20'
# 2020-11-02 18:03:31,095 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v.xu1.v.xu1a.vlim#branch           4.50478e-11'
# 2020-11-02 18:03:31,098 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v3#branch                                    0'
# 2020-11-02 18:03:31,099 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                            0.0284026'
# 2020-11-02 18:03:31,101 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                            -0.028388'
# 2020-11-02 18:03:31,104 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v.xu1.v.xu1b.vln#branch           -2.50009e-11'
# 2020-11-02 18:03:31,106 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v.xu1.v.xu1b.vlp#branch           -2.50007e-11'
# 2020-11-02 18:03:31,108 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v.xu1.v.xu1b.ve#branch             2.60808e-11'
# 2020-11-02 18:03:31,111 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v.xu1.v.xu1b.vc#branch            -1.03846e-07'
# 2020-11-02 18:03:31,113 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v.xu1.v.xu1b.vb#branch            -1.28927e-07'
# 2020-11-02 18:03:31,116 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v.xu1.v.xu1a.vln#branch           -2.50008e-11'
# 2020-11-02 18:03:31,118 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v.xu1.v.xu1a.vlp#branch           -2.50008e-11'
# 2020-11-02 18:03:31,120 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v.xu1.v.xu1a.ve#branch             1.28008e-11'
# 2020-11-02 18:03:31,121 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v.xu1.v.xu1a.vc#branch             1.28008e-11'
# 2020-11-02 18:03:31,123 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v.xu1.v.xu1a.vb#branch            -2.17983e-14'
# 2020-11-02 18:03:31,124 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout a$poly$e.xu1.e.xu1b.egnd#branch_1_0    -1.41567e-05'
# 2020-11-02 18:03:31,126 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout a$poly$e.xu1.e.xu1a.egnd#branch_1_0    -3.88527e-07'
# 2020-11-02 18:03:35,032 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00000e-01\r'
# 2020-11-02 18:03:35,282 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.05047e-01\r'
# 2020-11-02 18:03:35,480 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10001'
# 2020-11-02 18:03:35,482 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-02 18:03:35,484 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']

# %%
#simulate fuzz with a sine wave
fuzz = parser.build_circuit(ground=5)
fuzz.include(spice_library['TL072c'])
fuzz.include(spice_library['D1N4148'])
fuzz.V('1', '+15V', fuzz.gnd, 'DC 15')
fuzz.V('2', '-15V', fuzz.gnd, 'DC -15')
fuzz.V('3', 'IN', fuzz.gnd, 'DC 0V AC 0V PULSE(-5V 5V 0 0 0 2m 4m)')

class VoltageDivider(SubCircuitFactory):
    __name__ = 'voltage_divider'
    __nodes__ = ('n1', 'n2', 'n3' )
    def __init__(self, R=100@u_kΩ, w=0.4):
        super().__init__()
        self.R(1, 'n1', 'n2', R * w)
        self.R(2, 'n2', 'n3', R * (1.0-w) )

fuzz.subcircuit(VoltageDivider(R=100@u_kΩ, w=0.5))

simulator = fuzz.simulator(temperature=25, nominal_temperature=25)
analysis_fuzz_square = simulator.transient(step_time=1@u_us, start_time=100@u_ms, end_time=110@u_ms)
# Out:
# 2020-11-02 18:03:35,549 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/opamp/TL072-dual.lib
# .include /home/etienne/Documents/elektrophon/lib/spice/diode/1N4148.mod
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 50.0kOhm
# R2 n2 n3 50.0kOhm
# .ends voltage_divider
# C1 Net-_C1-Pad1_ IN 10u
# XU1 OUT Net-_C2-Pad2_ GND -15V NC_01 NC_02 NC_03 +15V TL072c
# C2 OUT Net-_C2-Pad2_ 47p
# R2 OUT Net-_C2-Pad2_ 100k
# R1 Net-_C2-Pad2_ Net-_C1-Pad1_ 3.3k
# D6 Net-_D4-Pad2_ OUT D1N4148
# D4 Net-_D2-Pad2_ Net-_D4-Pad2_ D1N4148
# D2 Net-_C2-Pad2_ Net-_D2-Pad2_ D1N4148
# D1 Net-_D1-Pad1_ Net-_C2-Pad2_ D1N4148
# D3 Net-_D3-Pad1_ Net-_D1-Pad1_ D1N4148
# D5 OUT Net-_D3-Pad1_ D1N4148
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 IN 0 DC 0V AC 0V PULSE(-5V 5V 0 0 0 2m 4m)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-02 18:03:35,550 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-02 18:03:35,553 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/opamp/TL072-dual.lib
# .include /home/etienne/Documents/elektrophon/lib/spice/diode/1N4148.mod
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 50.0kOhm
# R2 n2 n3 50.0kOhm
# .ends voltage_divider
# C1 Net-_C1-Pad1_ IN 10u
# XU1 OUT Net-_C2-Pad2_ GND -15V NC_01 NC_02 NC_03 +15V TL072c
# C2 OUT Net-_C2-Pad2_ 47p
# R2 OUT Net-_C2-Pad2_ 100k
# R1 Net-_C2-Pad2_ Net-_C1-Pad1_ 3.3k
# D6 Net-_D4-Pad2_ OUT D1N4148
# D4 Net-_D2-Pad2_ Net-_D4-Pad2_ D1N4148
# D2 Net-_C2-Pad2_ Net-_D2-Pad2_ D1N4148
# D1 Net-_D1-Pad1_ Net-_C2-Pad2_ D1N4148
# D3 Net-_D3-Pad1_ Net-_D1-Pad1_ D1N4148
# D5 OUT Net-_D3-Pad1_ D1N4148
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 IN 0 DC 0V AC 0V PULSE(-5V 5V 0 0 0 2m 4m)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-02 18:03:35,556 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-02 18:03:35,561 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-02 18:03:35,564 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b"stdout Reducing trtol to 1 for xspice 'A' devices"
# 2020-11-02 18:03:35,566 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-02 18:03:35,571 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-02 18:03:35,573 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-02 18:03:35,575 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-02 18:03:35,579 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-02 18:03:35,581 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c1-pad1_                      1.09706e-05'
# 2020-11-02 18:03:35,583 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout in                                          -5'
# 2020-11-02 18:03:35,586 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a.11                           -14.6546'
# 2020-11-02 18:03:35,587 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a.12                           -14.6545'
# 2020-11-02 18:03:35,591 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a.6                        -2.17983e-09'
# 2020-11-02 18:03:35,596 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a
- PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout a$poly$e.xu1.e.xu1b.egnd#branch_1_0    -1.41567e-05'
# 2020-11-02 18:03:35,715 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout a$poly$e.xu1.e.xu1a.egnd#branch_1_0    -3.88527e-07'
# 2020-11-02 18:03:39,191 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00000e-01\r'
# 2020-11-02 18:03:39,441 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.06873e-01\r'
# 2020-11-02 18:03:39,543 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10346'
# 2020-11-02 18:03:39,544 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-02 18:03:39,546 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']

# %%
#simulate fuzz with a sine wave
fuzz_triangle = parser.build_circuit(ground=5)
fuzz_triangle.include(spice_library['TL072c'])
fuzz_triangle.include(spice_library['D1N4148'])
fuzz_triangle.V('1', '+15V', fuzz_triangle.gnd, 'DC 15')
fuzz_triangle.V('2', '-15V', fuzz_triangle.gnd, 'DC -15')
fuzz_triangle.V('3', 'IN', fuzz_triangle.gnd, 'DC 0V AC 0V PULSE(0 1 0 0.002 0.002 0.002 0.004)')

class VoltageDivider(SubCircuitFactory):
    __name__ = 'voltage_divider'
    __nodes__ = ('n1', 'n2', 'n3' )
    def __init__(self, R=100@u_kΩ, w=0.4):
        super().__init__()
        self.R(1, 'n1', 'n2', R * w)
        self.R(2, 'n2', 'n3', R * (1.0-w) )

fuzz_triangle.subcircuit(VoltageDivider(R=100@u_kΩ, w=0.5))

simulator_triangle = fuzz_triangle.simulator(temperature=25, nominal_temperature=25)
analysis_fuzz_triangle = simulator_triangle.transient(step_time=1@u_us, start_time=100@u_ms, end_time=110@u_ms)
# Out:
# 2020-11-02 18:03:39,585 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/opamp/TL072-dual.lib
# .include /home/etienne/Documents/elektrophon/lib/spice/diode/1N4148.mod
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 50.0kOhm
# R2 n2 n3 50.0kOhm
# .ends voltage_divider
# C1 Net-_C1-Pad1_ IN 10u
# XU1 OUT Net-_C2-Pad2_ GND -15V NC_01 NC_02 NC_03 +15V TL072c
# C2 OUT Net-_C2-Pad2_ 47p
# R2 OUT Net-_C2-Pad2_ 100k
# R1 Net-_C2-Pad2_ Net-_C1-Pad1_ 3.3k
# D6 Net-_D4-Pad2_ OUT D1N4148
# D4 Net-_D2-Pad2_ Net-_D4-Pad2_ D1N4148
# D2 Net-_C2-Pad2_ Net-_D2-Pad2_ D1N4148
# D1 Net-_D1-Pad1_ Net-_C2-Pad2_ D1N4148
# D3 Net-_D3-Pad1_ Net-_D1-Pad1_ D1N4148
# D5 OUT Net-_D3-Pad1_ D1N4148
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 IN 0 DC 0V AC 0V PULSE(0 1 0 0.002 0.002 0.002 0.004)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-02 18:03:39,587 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-02 18:03:39,591 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/opamp/TL072-dual.lib
# .include /home/etienne/Documents/elektrophon/lib/spice/diode/1N4148.mod
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 50.0kOhm
# R2 n2 n3 50.0kOhm
# .ends voltage_divider
# C1 Net-_C1-Pad1_ IN 10u
# XU1 OUT Net-_C2-Pad2_ GND -15V NC_01 NC_02 NC_03 +15V TL072c
# C2 OUT Net-_C2-Pad2_ 47p
# R2 OUT Net-_C2-Pad2_ 100k
# R1 Net-_C2-Pad2_ Net-_C1-Pad1_ 3.3k
# D6 Net-_D4-Pad2_ OUT D1N4148
# D4 Net-_D2-Pad2_ Net-_D4-Pad2_ D1N4148
# D2 Net-_C2-Pad2_ Net-_D2-Pad2_ D1N4148
# D1 Net-_D1-Pad1_ Net-_C2-Pad2_ D1N4148
# D3 Net-_D3-Pad1_ Net-_D1-Pad1_ D1N4148
# D5 OUT Net-_D3-Pad1_ D1N4148
# V1 +15V 0 DC 15
# V2 -15V 0 DC -15
# V3 IN 0 DC 0V AC 0V PULSE(0 1 0 0.002 0.002 0.002 0.004)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-02 18:03:39,593 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-02 18:03:39,596 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-02 18:03:39,598 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b"stdout Reducing trtol to 1 for xspice 'A' devices"
# 2020-11-02 18:03:39,599 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-02 18:03:39,604 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-02 18:03:39,605 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-02 18:03:39,606 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-02 18:03:39,612 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-02 18:03:39,615 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c1-pad1_                      1.09706e-05'
# 2020-11-02 18:03:39,616 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout in                                           0'
# 2020-11-02 18:03:39,617 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a.11                           -14.6546'
# 2020-11-02 18:03:39,621 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a.12                           -14.6545'
# 2020-11-02 18:03:39,623 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a.6                        -2.17983e-09'
# 2020-11-02 18:03:39,625 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a.7                          1.5387e-05'
# 2020-11-02 18:03:39,626 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout out                                1.53802e-05'
# 2020-11-02 18:03:39,627 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a.53                               12.8'
# 2020-11-02 18:03:39,628 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a.54                              -12.8'
# 2020-11-02 18:03:39,629 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a.90                        4.50478e-08'
# 2020-11-02 18:03:39,631 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a.91                                 25'
# 2020-11-02 18:03:39,632 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a.92                                -25'
# 2020-11-02 18:03:39,633 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout -15v                                       -15'
# 2020-11-02 18:03:39,636 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +15v                                        15'
# 2020-11-02 18:03:39,637 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a.99                                  0'
# 2020-11-02 18:03:39,638 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a.10                          -0.398582'
# 2020-11-02 18:03:39,640 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c2-pad2_                      1.09706e-05'
# 2020-11-02 18:03:39,641 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout xu1.xu1a
fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, sharex=False, figsize=(18, 6))

#plot the image
#img_diffpair_path = directory_path.joinpath('diffpair', 'diffpair.png')
#img_diffpair = mpimg.imread(str(img_diffpair_path))
#im = ax0.imshow(img_diffpair)
#ax0.axis('off')
#ax0.set_title('long tailed pair differential amplifier', y=-0.2)
        
#plot with envelope
ax1.plot(analysis_fuzz_sine['IN'].abscissa*1000, analysis_fuzz_sine['IN'], c='grey')  # envelope input (scaled)
ax1.plot(analysis_fuzz_sine['OUT'].abscissa*1000, analysis_fuzz_sine['OUT'], c='orange')  # differential output
ax1.grid()
ax1.set_xlabel('t [ms]')
ax1.set_ylabel('[V]')
ax1.set_title('output with a cv envelope', y=-0.2)

#plot with envelope
ax2.plot(analysis_fuzz_square['IN'].abscissa*1000, analysis_fuzz_square['IN'], c='grey')  # envelope input (scaled)
ax2.plot(analysis_fuzz_square['OUT'].abscissa*1000, analysis_fuzz_square['OUT'], c='orange')  # differential output
ax2.grid()
ax2.set_xlabel('t [ms]')
ax2.set_ylabel('[V]')
ax2.set_title('output with a cv envelope', y=-0.2)

#plot with envelope
ax0.plot(analysis_fuzz_triangle['IN'].abscissa*1000, analysis_fuzz_triangle['IN'], c='grey')  # envelope input (scaled)
ax0.plot(analysis_fuzz_triangle['OUT'].abscissa*1000, analysis_fuzz_triangle['OUT'], c='orange')  # differential output
ax0.grid()
ax0.set_xlabel('t [ms]')
ax0.set_ylabel('[V]')
ax0.set_title('output with a cv envelope', y=-0.2)

plt.show()
# Out:
# 2020-11-02 18:03:43,074 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'multiply'> is NEW_UNIT
# 2020-11-02 18:03:43,078 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'multiply'> is NEW_UNIT
# 2020-11-02 18:03:43,084 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'multiply'> is NEW_UNIT
# 2020-11-02 18:03:43,088 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'multiply'> is NEW_UNIT
# 2020-11-02 18:03:43,093 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'multiply'> is NEW_UNIT
# 2020-11-02 18:03:43,097 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'multiply'> is NEW_UNIT

# %% [markdown]
# more promising is it to use a four quadrant multiplier, also known as gilbert cell. the gilbert cell is designed around two differential amplifiers. the carrier signal switches between those. the result is a multiplication of the input voltages. the gilbert cell is mostly used for amplitude modulation in radio transmission. if you look at the integratd circuits like the 633 it can modulate signals up in the gigahertz range. the gilbert cell is not described in all details here, there is a good introduction from w2aew [[4][4]].

# %% [markdown]
# this is not real amplitude modulation. when the signal is negative the phase of the output is inverted. this can be adjusted by the bias voltage of the control voltage. the control voltage has to be positive at all time.

# %% [markdown]
# ## *construction*
#
# for the final circuit input and output buffering and biasing is needed. the buffering is done with opamps.

# %% [markdown]
# first we design the input stage. the input voltage for the X signal should be 10mV and 20mV for the control voltage.

# %% [markdown]
# ## *references*
#
# - [VCA Techniques Investigated][1] Rod Elliott (ESP)
# - [Popular Electronics][2] Keyiing and VCA citcuits for electronic music instruments
# - [VCA-1][3] Thomas Henry CA3080 vca
# - [VCA-3][4] René Schmitz differential pair vca
# - [#223][5]: Basics of the Gilbert Cell | Analog Multiplier | Mixer | Modulator
# - [#224][6]: AM & DSB-SC Modulation with the Gilbert Cell
# - [Analog Devices][8]: Analog multiplier application guide
# - [AD633][9]: Datasheet
#
#
#
#
# [1]: https://static1.squarespace.com/static/5e6e99e8bd2f8a6de8454feb/t/5e77db16e8ff44374c24b124/1584913176675/MBD+BOM+and+build.pdf
# [2]: https://www.diystompboxes.com/smfforum/index.php?topic=118397.0
# [3]: https://www.diystompboxes.com/smfforum/index.php?topic=99779.0
