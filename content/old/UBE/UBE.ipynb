# %%
# Just the normal prequisites for using matplotlib and numpy in a Jupyter notebook
# %matplotlib inline
# Use the svg backend, in my opinion it just makes better looking plots
# %config InlineBackend.figure_format = 'svg'

import PySpice.Logging.Logging as Logging
logger = Logging.setup_logging( logging_level='DEBUG')

import os
import sys
import IPython
from scipy import signal
import scipy.fftpack
from PySpice.Unit import *
from PySpice.Spice.Parser import SpiceParser
from PySpice.Spice.Netlist import Circuit, SubCircuit, SubCircuitFactory
from PySpice.Spice.Library import SpiceLibrary
from PySpice.Probe.Plot import plot
from PySpice.Doc.ExampleTools import find_libraries
from PySpice.Math import *
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt
import unittest

sys.path.append('../../lib/python')
import Spice2Wav.Spice2Wav as wav

import PySpice.Logging.Logging as Logging
logger = Logging.setup_logging()

directory_path = Path(os.path.abspath('')).resolve().parent.parent
spice_libraries_path = directory_path.joinpath("lib", "spice")
spice_library = SpiceLibrary(spice_libraries_path)

directory_path = Path(os.path.abspath('')).resolve()
# Out:
# 2020-11-07 12:51:53,778 - PySpice.Spice.Netlist.__new__ - DEBUG - Element don't define a __pins__ attribute
# 2020-11-07 12:51:53,780 - PySpice.Spice.Netlist.__new__ - DEBUG - FixedPinElement don't define a __pins__ attribute
# 2020-11-07 12:51:53,782 - PySpice.Spice.Netlist.__new__ - DEBUG - SubCircuitElement don't define a __pins__ attribute
# 2020-11-07 12:51:53,783 - PySpice.Spice.Netlist.__new__ - DEBUG - Resistor don't define a __pins__ attribute
# 2020-11-07 12:51:53,784 - PySpice.Spice.Netlist.__new__ - DEBUG - SemiconductorResistor don't define a __pins__ attribute
# 2020-11-07 12:51:53,788 - PySpice.Spice.Netlist.__new__ - DEBUG - BehavioralResistor don't define a __pins__ attribute
# 2020-11-07 12:51:53,792 - PySpice.Spice.Netlist.__new__ - DEBUG - Capacitor don't define a __pins__ attribute
# 2020-11-07 12:51:53,797 - PySpice.Spice.Netlist.__new__ - DEBUG - SemiconductorCapacitor don't define a __pins__ attribute
# 2020-11-07 12:51:53,798 - PySpice.Spice.Netlist.__new__ - DEBUG - BehavioralCapacitor don't define a __pins__ attribute
# 2020-11-07 12:51:53,801 - PySpice.Spice.Netlist.__new__ - DEBUG - Inductor don't define a __pins__ attribute
# 2020-11-07 12:51:53,802 - PySpice.Spice.Netlist.__new__ - DEBUG - BehavioralInductor don't define a __pins__ attribute
# 2020-11-07 12:51:53,803 - PySpice.Spice.Netlist.__new__ - DEBUG - CoupledInductor don't define a __pins__ attribute
# 2020-11-07 12:51:53,806 - PySpice.Spice.Netlist.__new__ - DEBUG - VoltageControlledSwitch don't define a __pins__ attribute
# 2020-11-07 12:51:53,807 - PySpice.Spice.Netlist.__new__ - DEBUG - CurrentControlledSwitch don't define a __pins__ attribute
# 2020-11-07 12:51:53,811 - PySpice.Spice.Netlist.__new__ - DEBUG - VoltageSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,814 - PySpice.Spice.Netlist.__new__ - DEBUG - CurrentSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,815 - PySpice.Spice.Netlist.__new__ - DEBUG - VoltageControlledCurrentSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,816 - PySpice.Spice.Netlist.__new__ - DEBUG - VoltageControlledVoltageSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,818 - PySpice.Spice.Netlist.__new__ - DEBUG - CurrentControlledCurrentSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,821 - PySpice.Spice.Netlist.__new__ - DEBUG - CurrentControlledVoltageSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,826 - PySpice.Spice.Netlist.__new__ - DEBUG - BehavioralSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,828 - PySpice.Spice.Netlist.__new__ - DEBUG - NonLinearVoltageSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,830 - PySpice.Spice.Netlist.__new__ - DEBUG - NonLinearCurrentSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,832 - PySpice.Spice.Netlist.__new__ - DEBUG - JunctionFieldEffectTransistor don't define a __pins__ attribute
# 2020-11-07 12:51:53,833 - PySpice.Spice.Netlist.__new__ - DEBUG - Mesfet don't define a __pins__ attribute
# 2020-11-07 12:51:53,834 - PySpice.Spice.Netlist.__new__ - DEBUG - LosslessTransmissionLine don't define a __pins__ attribute
# 2020-11-07 12:51:53,836 - PySpice.Spice.Netlist.__new__ - DEBUG - LossyTransmission don't define a __pins__ attribute
# 2020-11-07 12:51:53,839 - PySpice.Spice.Netlist.__new__ - DEBUG - CoupledMulticonductorLine don't define a __pins__ attribute
# 2020-11-07 12:51:53,842 - PySpice.Spice.Netlist.__new__ - DEBUG - SingleLossyTransmissionLine don't define a __pins__ attribute
# 2020-11-07 12:51:53,843 - PySpice.Spice.Netlist.__new__ - DEBUG - XSpiceElement don't define a __pins__ attribute
# 2020-11-07 12:51:53,845 - PySpice.Spice.Netlist.__new__ - DEBUG - GSSElement don't define a __pins__ attribute
# 2020-11-07 12:51:53,849 - PySpice.Spice.Netlist.__new__ - DEBUG - SinusoidalVoltageSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,851 - PySpice.Spice.Netlist.__new__ - DEBUG - SinusoidalCurrentSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,854 - PySpice.Spice.Netlist.__new__ - DEBUG - AcLine don't define a __pins__ attribute
# 2020-11-07 12:51:53,857 - PySpice.Spice.Netlist.__new__ - DEBUG - PulseVoltageSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,858 - PySpice.Spice.Netlist.__new__ - DEBUG - PulseCurrentSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,862 - PySpice.Spice.Netlist.__new__ - DEBUG - ExponentialVoltageSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,864 - PySpice.Spice.Netlist.__new__ - DEBUG - ExponentialCurrentSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,865 - PySpice.Spice.Netlist.__new__ - DEBUG - PieceWiseLinearVoltageSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,867 - PySpice.Spice.Netlist.__new__ - DEBUG - PieceWiseLinearCurrentSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,870 - PySpice.Spice.Netlist.__new__ - DEBUG - SingleFrequencyFMVoltageSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,871 - PySpice.Spice.Netlist.__new__ - DEBUG - SingleFrequencyFMCurrentSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,873 - PySpice.Spice.Netlist.__new__ - DEBUG - AmplitudeModulatedVoltageSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,874 - PySpice.Spice.Netlist.__new__ - DEBUG - AmplitudeModulatedCurrentSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,878 - PySpice.Spice.Netlist.__new__ - DEBUG - RandomVoltageSource don't define a __pins__ attribute
# 2020-11-07 12:51:53,880 - PySpice.Spice.Netlist.__new__ - DEBUG - RandomCurrentSource don't define a __pins__ attribute

# %% [markdown]
# ![module](https://img.shields.io/badge/module-shin%20ey-yellow) ![status](https://img.shields.io/badge/status-work%20in%20progress-orange)
#
# ## *shin ey*
#
# <a href="https://photos.app.goo.gl/pg6iZUC32rTKX5LC7"><img src="https://spielhuus.github.io/elektrophon/images/kontrast-logo-tmb.jpg" height="300px" align="right"></a>
#
# ***table of contents***
#
# * [*about*](#about)
# * [*construction*](#construction)
# * [*calibration*](#calibration)
# * [*usage*](#usage)
# * [*credits*](#credits)
# * [*links*](#links)
# * [*changelog*](#changelog)
#
# <br/><br/><br/><br/>
#
# ## *about*
#
# pegel is a voltage controlled amplifier (vca). there are various designs to implement a vca. rod elliott (ESP) has an article on vca techniques [[1][1]]. diy synthesizer modules are usualy designed with an integrated vca chip [[2][2]]  or with a differential amplifier [[3][3]]. the integrated vca chips are either obsolete or rather expensive. the differential amplifier can be built with transistors only. the design has some downsides. even in the simulation the result is not symetryc and has a dc offset from the control voltage. this needs a lot of trimming to get an accurate result. but the biggest downside is, that this design can not do proper amplitude modulation (am). when the carrier signal goes below zero the base signal is completely muted.

# %%
#load the diffpair schema
kicad_netlist_path = directory_path.joinpath('main', 'main.cir')
parser = SpiceParser(path=str(kicad_netlist_path))

# %%
#simulate fuzz with a sine wave
lp = parser.build_circuit(ground=5)
lp.include(spice_library['CD4069UBhex'])
lp.include(spice_library['D1N4148'])
lp.V('1', '+5V', lp.gnd, 'DC 5')
#lp.V('2', 'IN', lp.gnd, 'DC 0V AC 1.5V pulse(-1.5V +1.5V 0 2m 2m 0m 2m)')
lp.V('2', 'IN', lp.gnd, 'DC 0V AC 1.5V sine(0 0.1V 1k)')

class VoltageDivider1(SubCircuitFactory):
    __name__ = 'voltage_divider_1'
    __nodes__ = ('n1', 'n2', 'n3' )
    def __init__(self, R=100@u_kΩ, w=0.4):
        super().__init__()
        self.R(1, 'n1', 'n2', R * w)
        self.R(2, 'n2', 'n3', R * (1.0-w) )

class VoltageDivider2(SubCircuitFactory):
    __name__ = 'voltage_divider_2'
    __nodes__ = ('n1', 'n2', 'n3' )
    def __init__(self, R=100@u_kΩ, w=0.4):
        super().__init__()
        self.R(1, 'n1', 'n2', R * w)
        self.R(2, 'n2', 'n3', R * (1.0-w) )


for subcircuit in ( VoltageDivider1(R=500@u_kΩ, w=0.9999999), VoltageDivider2(R=500@u_kΩ, w=0.00001) ):
    lp.subcircuit(subcircuit)

simulator = lp.simulator(temperature=25, nominal_temperature=25)
#analysis_lp = simulator.ac(start_frequency=10@u_Hz, stop_frequency=10@u_kHz, number_of_points=10,  variation='dec')
analysis_lp = simulator.transient(step_time=1@u_us, start_time=100@u_ms, end_time=110@u_ms)
# Out:
# 2020-11-07 12:51:54,065 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.new_instance - DEBUG - New instance for id 0
# 2020-11-07 12:51:54,067 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._load_library - DEBUG - Set locale LC_NUMERIC to C
# 2020-11-07 12:51:54,145 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._load_library - DEBUG - Load library libngspice.so
# 2020-11-07 12:51:54,180 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stderr Error: bad type for debug var'
# 2020-11-07 12:51:54,181 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Error: bad type for debug var
# 2020-11-07 12:51:54,183 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stderr Warning: ngspice compiled without debug messages'
# 2020-11-07 12:51:54,187 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - WARNING - Warning: ngspice compiled without debug messages
# 2020-11-07 12:51:54,190 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ******'
# 2020-11-07 12:51:54,192 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** ngspice-31 shared library'
# 2020-11-07 12:51:54,195 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** Creation Date: Sun Oct 27 09:07:06 UTC 2019'
# 2020-11-07 12:51:54,199 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ******'
# 2020-11-07 12:51:54,208 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: version -f
# 2020-11-07 12:51:54,211 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ******'
# 2020-11-07 12:51:54,213 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** ngspice-31 : Circuit level simulation program'
# 2020-11-07 12:51:54,215 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** The U. C. Berkeley CAD Group'
# 2020-11-07 12:51:54,217 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** Copyright 1985-1994, Regents of the University of California.'
# 2020-11-07 12:51:54,220 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** Please get your ngspice manual from http://ngspice.sourceforge.net/docs.html'
# 2020-11-07 12:51:54,223 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** Please file your bug-reports at http://ngspice.sourceforge.net/bugrep.html'
# 2020-11-07 12:51:54,226 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** Creation Date: Sun Oct 27 09:07:06 UTC 2019'
# 2020-11-07 12:51:54,230 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout **'
# 2020-11-07 12:51:54,236 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** CIDER 1.b1 (CODECS simulator) included'
# 2020-11-07 12:51:54,238 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** XSPICE extensions included'
# 2020-11-07 12:51:54,240 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b"stdout ** Relevant compilation options (refer to user's manual):"
# 2020-11-07 12:51:54,243 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** OpenMP multithreading for BSIM3, BSIM4 enabled'
# 2020-11-07 12:51:54,245 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ** X11 interface not compiled into ngspice'
# 2020-11-07 12:51:54,252 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout **'
# 2020-11-07 12:51:54,255 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ******'
# 2020-11-07 12:51:54,258 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._get_version - DEBUG - Ngspice version 31 with extensions: CIDER, XSPICE
# 2020-11-07 12:51:54,261 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: set nomoremode
# 2020-11-07 12:51:54,266 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/cmos/CD4069UB-hex.lib
# .include /home/etienne/Documents/elektrophon/lib/spice/diode/1N4148.mod
# .subckt voltage_divider_1 n1 n2 n3
# R1 n1 n2 499.99995kOhm
# R2 n2 n3 4.999999997368221e-05kOhm
# .ends voltage_divider_1
#
# .subckt voltage_divider_2 n1 n2 n3
# R1 n1 n2 0.005kOhm
# R2 n2 n3 499.995kOhm
# .ends voltage_divider_2
# XU1 Net-_R2-Pad1_ Net-_C2-Pad2_ Net-_R4-Pad1_ Net-_RV1-Pad2_ Net-_C3-Pad1_ Net-_C4-Pad2_ GND Net-_C6-Pad1_ Net-_C6-Pad2_ Net-_C9-Pad2_ Net-_R11-Pad1_ GND GND +5V CD4069UBhex
# R1 IN GND 1Meg
# R2 Net-_R2-Pad1_ Net-_C1-Pad1_ 470k
# R3 Net-_C2-Pad2_ Net-_R2-Pad1_ 470k
# R4 Net-_R4-Pad1_ Net-_C2-Pad1_ 100k
# C1 Net-_C1-Pad1_ IN 10n
# C2 Net-_C2-Pad1_ Net-_C2-Pad2_ 2.2n
# R5 Net-_R5-Pad1_ Net-_R4-Pad1_ 100k
# XRV1 Net-_R5-Pad1_ Net-_RV1-Pad2_ Net-_R6-Pad2_ voltage_divider_1
# R6 Net-_C3-Pad2_ Net-_R6-Pad2_ 10k
# C3 Net-_C3-Pad1_ Net-_C3-Pad2_ 470n
# R7 Net-_C4-Pad2_ Net-_C3-Pad1_ 1Meg
# D2 Net-_C3-Pad1_ Net-_C4-Pad2_ D1N4148
# D1 Net-_C4-Pad2_ Net-_C3-Pad1_ D1N4148
# R8 Net-_C5-Pad2_ Net-_C4-Pad1_ 100k
# C4 Net-_C4-Pad1_ Net-_C4-Pad2_ 100n
# C5 GND Net-_C5-Pad2_ 1.5n
# R9 Net-_R9-Pad1_ Net-_C5-Pad2_ 10k
# XRV2 Net-_C6-Pad2_ Net-_C6-Pad2_ Net-_R9-Pad1_ voltage_divider_2
# C6 Net-_C6-Pad1_ Net-_C6-Pad2_ 150p
# R10 Net-_C6-Pad1_ Net-_C5-Pad2_ 100k
# R11 Net-_R11-Pad1_ Net-_C7-Pad1_ 100k
# C7 Net-_C7-Pad1_ Net-_C6-Pad1_ 100n
# R13 Net-_C9-Pad2_ Net-_R11-Pad1_ 220k
# C9 OUT Net-_C9-Pad2_ 100n
# C8 Net-_C8-Pad1_ Net-_C2-Pad2_ 100n
# R12 Net-_R11-Pad1_ Net-_C8-Pad1_ 100k
# R14 GND OUT 1k
# V1 +5V 0 DC 5
# V2 IN 0 DC 0V AC 1.5V sine(0 0.1V 1k)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-07 12:51:54,268 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-07 12:51:54,271 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/cmos/CD4069UB-hex.lib
# .include /home/etienne/Documents/elektrophon/lib/spice/diode/1N4148.mod
# .subckt voltage_divider_1 n1 n2 n3
# R1 n1 n2 499.99995kOhm
# R2 n2 n3 4.999999997368221e-05kOhm
# .ends voltage_divider_1
#
# .subckt voltage_divider_2 n1 n2 n3
# R1 n1 n2 0.005kOhm
# R2 n2 n3 499.995kOhm
# .ends voltage_divider_2
# XU1 Net-_R2-Pad1_ Net-_C2-Pad2_ Net-_R4-Pad1_ Net-_RV1-Pad2_ Net-_C3-Pad1_ Net-_C4-Pad2_ GND Net-_C6-Pad1_ Net-_C6-Pad2_ Net-_C9-Pad2_ Net-_R11-Pad1_ GND GND +5V CD4069UBhex
# R1 IN GND 1Meg
# R2 Net-_R2-Pad1_ Net-_C1-Pad1_ 470k
# R3 Net-_C2-Pad2_ Net-_R2-Pad1_ 470k
# R4 Net-_R4-Pad1_ Net-_C2-Pad1_ 100k
# C1 Net-_C1-Pad1_ IN 10n
# C2 Net-_C2-Pad1_ Net-_C2-Pad2_ 2.2n
# R5 Net-_R5-Pad1_ Net-_R4-Pad1_ 100k
# XRV1 Net-_R5-Pad1_ Net-_RV1-Pad2_ Net-_R6-Pad2_ voltage_divider_1
# R6 Net-_C3-Pad2_ Net-_R6-Pad2_ 10k
# C3 Net-_C3-Pad1_ Net-_C3-Pad2_ 470n
# R7 Net-_C4-Pad2_ Net-_C3-Pad1_ 1Meg
# D2 Net-_C3-Pad1_ Net-_C4-Pad2_ D1N4148
# D1 Net-_C4-Pad2_ Net-_C3-Pad1_ D1N4148
# R8 Net-_C5-Pad2_ Net-_C4-Pad1_ 100k
# C4 Net-_C4-Pad1_ Net-_C4-Pad2_ 100n
# C5 GND Net-_C5-Pad2_ 1.5n
# R9 Net-_R9-Pad1_ Net-_C5-Pad2_ 10k
# XRV2 Net-_C6-Pad2_ Net-_C6-Pad2_ Net-_R9-Pad1_ voltage_divider_2
# C6 Net-_C6-Pad1_ Net-_C6-Pad2_ 150p
# R10 Net-_C6-Pad1_ Net-_C5-Pad2_ 100k
# R11 Net-_R11-Pad1_ Net-_C7-Pad1_ 100k
# C7 Net-_C7-Pad1_ Net-_C6-Pad1_ 100n
# R13 Net-_C9-Pad2_ Net-_R11-Pad1_ 220k
# C9 OUT Net-_C9-Pad2_ 100n
# C8 Net-_C8-Pad1_ Net-_C2-Pad2_ 100n
# R12 Net-_R11-Pad1_ Net-_C8-Pad1_ 100k
# R14 GND OUT 1k
# V1 +5V 0 DC 5
# V2 IN 0 DC 0V AC 1.5V sine(0 0.1V 1k)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-07 12:51:54,291 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-07 12:51:54,296 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-07 12:51:54,299 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-07 12:51:54,301 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-07 12:51:54,302 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-07 12:51:54,305 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-07 12:51:54,308 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-07 12:51:54,310 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c2-pad2_                          2.10156'
# 2020-11-07 12:51:54,312 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r2-pad1_                          2.10156'
# 2020-11-07 12:51:54,315 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +5v                                          5'
# 2020-11-07 12:51:54,317 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_rv1-pad2_                         2.10156'
# 2020-11-07 12:51:54,319 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r4-pad1_                          2.10156'
# 2020-11-07 12:51:54,322 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c4-pad2_                          2.10156'
# 2020-11-07 12:51:54,324 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c3-pad1_                          2.10156'
# 2020-11-07 12:51:54,327 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c6-pad1_                          2.10156'
# 2020-11-07 12:51:54,328 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c6-pad2_                          2.10156'
# 2020-11-07 12:51:54,332 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c9-pad2_                          2.10156'
# 2020-11-07 12:51:54,334 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r11-pad1_                         2.10156'
# 2020-11-07 12:51:54,335 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout in                                           0'
# 2020-11-07 12:51:54,337 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c1-pad1_                          2.10156'
# 2020-11-07 12:51:54,339 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c2-pad1_                          2.10156'
# 2020-11-07 12:51:54,342 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r5-pad1_                          2.10156'
# 2020-11-07 12:51:54,349 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r6-pad2_                          2.10156'
# 2020-11-07 12:51:54,351 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c3-pad2_                          2.10156'
# 2020-11-07 12:51:54,353 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c5-pad2_                          2.10156'
# 2020-11-07 12:51:54,354 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c4-pad1_                          2.10156'
# 2020-11-07 12:51:54,356 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r9-pad1_                          2.10156'
# 2020-11-07 12:51:54,360 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c7-pad1_                          2.10156'
# 2020-11-07 12:51:54,363 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout out                                          0'
# 2020-11-07 12:51:54,365 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c8-pad1_                          2.10156'
# 2020-11-07 12:51:54,366 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                                    0'
# 2020-11-07 12:51:54,368 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                          -0.00286148'
# 2020-11-07 12:51:57,717 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00000e-01\r'
# 2020-11-07 12:51:57,966 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.08418e-01\r'
# 2020-11-07 12:51:58,030 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10001'
# 2020-11-07 12:51:58,031 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-07 12:51:58,032 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']

# %%
#simulate fuzz with a sine wave
lp = parser.build_circuit(ground=5)
lp.include(spice_library['CD4069UBhex'])
lp.include(spice_library['D1N4148'])
lp.V('1', '+5V', lp.gnd, 'DC 5')
#lp.V('2', 'IN', lp.gnd, 'DC 0V AC 1.5V pulse(-1.5V +1.5V 0 2m 2m 0m 2m)')
lp.V('2', 'IN', lp.gnd, 'DC 0V AC 1.5V sine(0 0.1V 1k)')

class VoltageDivider1(SubCircuitFactory):
    __name__ = 'voltage_divider_1'
    __nodes__ = ('n1', 'n2', 'n3' )
    def __init__(self, R=100@u_kΩ, w=0.4):
        super().__init__()
        self.R(1, 'n1', 'n2', R * w)
        self.R(2, 'n2', 'n3', R * (1.0-w) )

class VoltageDivider2(SubCircuitFactory):
    __name__ = 'voltage_divider_2'
    __nodes__ = ('n1', 'n2', 'n3' )
    def __init__(self, R=100@u_kΩ, w=0.4):
        super().__init__()
        self.R(1, 'n1', 'n2', R * w)
        self.R(2, 'n2', 'n3', R * (1.0-w) )


for subcircuit in ( VoltageDivider1(R=500@u_kΩ, w=0.0000001), VoltageDivider2(R=500@u_kΩ, w=0.00001) ):
    lp.subcircuit(subcircuit)

simulator = lp.simulator(temperature=25, nominal_temperature=25)
#analysis_lp = simulator.ac(start_frequency=10@u_Hz, stop_frequency=10@u_kHz, number_of_points=10,  variation='dec')
analysis_lp2 = simulator.transient(step_time=1@u_us, start_time=100@u_ms, end_time=110@u_ms)
# Out:
# 2020-11-07 12:51:58,112 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/cmos/CD4069UB-hex.lib
# .include /home/etienne/Documents/elektrophon/lib/spice/diode/1N4148.mod
# .subckt voltage_divider_1 n1 n2 n3
# R1 n1 n2 4.9999999999999996e-05kOhm
# R2 n2 n3 499.99995kOhm
# .ends voltage_divider_1
#
# .subckt voltage_divider_2 n1 n2 n3
# R1 n1 n2 0.005kOhm
# R2 n2 n3 499.995kOhm
# .ends voltage_divider_2
# XU1 Net-_R2-Pad1_ Net-_C2-Pad2_ Net-_R4-Pad1_ Net-_RV1-Pad2_ Net-_C3-Pad1_ Net-_C4-Pad2_ GND Net-_C6-Pad1_ Net-_C6-Pad2_ Net-_C9-Pad2_ Net-_R11-Pad1_ GND GND +5V CD4069UBhex
# R1 IN GND 1Meg
# R2 Net-_R2-Pad1_ Net-_C1-Pad1_ 470k
# R3 Net-_C2-Pad2_ Net-_R2-Pad1_ 470k
# R4 Net-_R4-Pad1_ Net-_C2-Pad1_ 100k
# C1 Net-_C1-Pad1_ IN 10n
# C2 Net-_C2-Pad1_ Net-_C2-Pad2_ 2.2n
# R5 Net-_R5-Pad1_ Net-_R4-Pad1_ 100k
# XRV1 Net-_R5-Pad1_ Net-_RV1-Pad2_ Net-_R6-Pad2_ voltage_divider_1
# R6 Net-_C3-Pad2_ Net-_R6-Pad2_ 10k
# C3 Net-_C3-Pad1_ Net-_C3-Pad2_ 470n
# R7 Net-_C4-Pad2_ Net-_C3-Pad1_ 1Meg
# D2 Net-_C3-Pad1_ Net-_C4-Pad2_ D1N4148
# D1 Net-_C4-Pad2_ Net-_C3-Pad1_ D1N4148
# R8 Net-_C5-Pad2_ Net-_C4-Pad1_ 100k
# C4 Net-_C4-Pad1_ Net-_C4-Pad2_ 100n
# C5 GND Net-_C5-Pad2_ 1.5n
# R9 Net-_R9-Pad1_ Net-_C5-Pad2_ 10k
# XRV2 Net-_C6-Pad2_ Net-_C6-Pad2_ Net-_R9-Pad1_ voltage_divider_2
# C6 Net-_C6-Pad1_ Net-_C6-Pad2_ 150p
# R10 Net-_C6-Pad1_ Net-_C5-Pad2_ 100k
# R11 Net-_R11-Pad1_ Net-_C7-Pad1_ 100k
# C7 Net-_C7-Pad1_ Net-_C6-Pad1_ 100n
# R13 Net-_C9-Pad2_ Net-_R11-Pad1_ 220k
# C9 OUT Net-_C9-Pad2_ 100n
# C8 Net-_C8-Pad1_ Net-_C2-Pad2_ 100n
# R12 Net-_R11-Pad1_ Net-_C8-Pad1_ 100k
# R14 GND OUT 1k
# V1 +5V 0 DC 5
# V2 IN 0 DC 0V AC 1.5V sine(0 0.1V 1k)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-07 12:51:58,116 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-07 12:51:58,123 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/cmos/CD4069UB-hex.lib
# .include /home/etienne/Documents/elektrophon/lib/spice/diode/1N4148.mod
# .subckt voltage_divider_1 n1 n2 n3
# R1 n1 n2 4.9999999999999996e-05kOhm
# R2 n2 n3 499.99995kOhm
# .ends voltage_divider_1
#
# .subckt voltage_divider_2 n1 n2 n3
# R1 n1 n2 0.005kOhm
# R2 n2 n3 499.995kOhm
# .ends voltage_divider_2
# XU1 Net-_R2-Pad1_ Net-_C2-Pad2_ Net-_R4-Pad1_ Net-_RV1-Pad2_ Net-_C3-Pad1_ Net-_C4-Pad2_ GND Net-_C6-Pad1_ Net-_C6-Pad2_ Net-_C9-Pad2_ Net-_R11-Pad1_ GND GND +5V CD4069UBhex
# R1 IN GND 1Meg
# R2 Net-_R2-Pad1_ Net-_C1-Pad1_ 470k
# R3 Net-_C2-Pad2_ Net-_R2-Pad1_ 470k
# R4 Net-_R4-Pad1_ Net-_C2-Pad1_ 100k
# C1 Net-_C1-Pad1_ IN 10n
# C2 Net-_C2-Pad1_ Net-_C2-Pad2_ 2.2n
# R5 Net-_R5-Pad1_ Net-_R4-Pad1_ 100k
# XRV1 Net-_R5-Pad1_ Net-_RV1-Pad2_ Net-_R6-Pad2_ voltage_divider_1
# R6 Net-_C3-Pad2_ Net-_R6-Pad2_ 10k
# C3 Net-_C3-Pad1_ Net-_C3-Pad2_ 470n
# R7 Net-_C4-Pad2_ Net-_C3-Pad1_ 1Meg
# D2 Net-_C3-Pad1_ Net-_C4-Pad2_ D1N4148
# D1 Net-_C4-Pad2_ Net-_C3-Pad1_ D1N4148
# R8 Net-_C5-Pad2_ Net-_C4-Pad1_ 100k
# C4 Net-_C4-Pad1_ Net-_C4-Pad2_ 100n
# C5 GND Net-_C5-Pad2_ 1.5n
# R9 Net-_R9-Pad1_ Net-_C5-Pad2_ 10k
# XRV2 Net-_C6-Pad2_ Net-_C6-Pad2_ Net-_R9-Pad1_ voltage_divider_2
# C6 Net-_C6-Pad1_ Net-_C6-Pad2_ 150p
# R10 Net-_C6-Pad1_ Net-_C5-Pad2_ 100k
# R11 Net-_R11-Pad1_ Net-_C7-Pad1_ 100k
# C7 Net-_C7-Pad1_ Net-_C6-Pad1_ 100n
# R13 Net-_C9-Pad2_ Net-_R11-Pad1_ 220k
# C9 OUT Net-_C9-Pad2_ 100n
# C8 Net-_C8-Pad1_ Net-_C2-Pad2_ 100n
# R12 Net-_R11-Pad1_ Net-_C8-Pad1_ 100k
# R14 GND OUT 1k
# V1 +5V 0 DC 5
# V2 IN 0 DC 0V AC 1.5V sine(0 0.1V 1k)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-07 12:51:58,126 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-07 12:51:58,130 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-07 12:51:58,131 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-07 12:51:58,133 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-07 12:51:58,137 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-07 12:51:58,142 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-07 12:51:58,143 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-07 12:51:58,146 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c2-pad2_                          2.10156'
# 2020-11-07 12:51:58,151 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r2-pad1_                          2.10156'
# 2020-11-07 12:51:58,158 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +5v                                          5'
# 2020-11-07 12:51:58,160 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_rv1-pad2_                         2.10156'
# 2020-11-07 12:51:58,162 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r4-pad1_                          2.10156'
# 2020-11-07 12:51:58,163 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c4-pad2_                          2.10156'
# 2020-11-07 12:51:58,167 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c3-pad1_                          2.10156'
# 2020-11-07 12:51:58,169 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c6-pad1_                          2.10156'
# 2020-11-07 12:51:58,171 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c6-pad2_                          2.10156'
# 2020-11-07 12:51:58,176 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c9-pad2_                          2.10156'
# 2020-11-07 12:51:58,180 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r11-pad1_                         2.10156'
# 2020-11-07 12:51:58,183 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout in                                           0'
# 2020-11-07 12:51:58,185 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c1-pad1_                          2.10156'
# 2020-11-07 12:51:58,189 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c2-pad1_                          2.10156'
# 2020-11-07 12:51:58,192 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r5-pad1_                          2.10156'
# 2020-11-07 12:51:58,197 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r6-pad2_                          2.10156'
# 2020-11-07 12:51:58,211 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c3-pad2_                          2.10156'
# 2020-11-07 12:51:58,213 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c5-pad2_                          2.10156'
# 2020-11-07 12:51:58,216 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c4-pad1_                          2.10156'
# 2020-11-07 12:51:58,218 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r9-pad1_                          2.10156'
# 2020-11-07 12:51:58,221 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c7-pad1_                          2.10156'
# 2020-11-07 12:51:58,223 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout out                                          0'
# 2020-11-07 12:51:58,225 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c8-pad1_                          2.10156'
# 2020-11-07 12:51:58,229 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                                    0'
# 2020-11-07 12:51:58,231 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                          -0.00286148'
# 2020-11-07 12:52:00,899 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00000e-01\r'
# 2020-11-07 12:52:01,149 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.07836e-01\r'
# 2020-11-07 12:52:01,219 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10001'
# 2020-11-07 12:52:01,220 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-07 12:52:01,221 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']

# %%
#plot the results
fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, sharex=False, figsize=(18, 6))

#plot the image
#img_diffpair_path = directory_path.joinpath('diffpair', 'diffpair.png')
#img_diffpair = mpimg.imread(str(img_diffpair_path))
#im = ax0.imshow(img_diffpair)
#ax0.axis('off')
#ax0.set_title('long tailed pair differential amplifier', y=-0.2)
        
#plot with envelope
#ax0.plot(analysis_lp['IN'].abscissa*1000, analysis_lp['IN'], c='grey')  # envelope input (scaled)
ax0.plot(analysis_lp['OUT'].abscissa*1000, analysis_lp['OUT'], c='orange')  # differential output
#ax0.plot(analysis_lp['Net-_C2-Pad2_'].abscissa*1000, analysis_lp['Net-_C2-Pad2_'], c='red')  # differential output
ax0.grid()
ax0.set_xlabel('t [ms]')
ax0.set_ylabel('[V]')
ax0.set_title('Filter Sweep', y=-0.2)

ax1.plot(analysis_lp2['OUT'].abscissa*1000, analysis_lp2['OUT'], c='orange')  # differential output
#ax1.plot(analysis_lp['Net-_C2-Pad2_'].abscissa*1000, analysis_lp['Net-_C2-Pad2_'], c='red')  # differential output
ax1.grid()
ax1.set_xlabel('t [ms]')
ax1.set_ylabel('[V]')
ax1.set_title('Filter Sweep', y=-0.2)

#plot with envelope
#ax2.plot(analysis_fuzz_square['IN'].abscissa*1000, analysis_fuzz_square['IN'], c='grey')  # envelope input (scaled)
#ax2.plot(analysis_fuzz_square['OUT'].abscissa*1000, analysis_fuzz_square['OUT'], c='orange')  # differential output
#ax2.grid()
#ax2.set_xlabel('t [ms]')
#ax2.set_ylabel('[V]')
#ax2.set_title('output with a cv envelope', y=-0.2)

plt.show()
# Out:
# 2020-11-07 12:52:01,362 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'multiply'> is NEW_UNIT
# 2020-11-07 12:52:01,368 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - DEBUG - Conversion for <ufunc 'multiply'> is NEW_UNIT

# %%
#simulate fuzz with a sine wave
fuzz = parser.build_circuit(ground=5)
fuzz.include(spice_library['BC547B'])
fuzz.include(spice_library['BC547B'])
fuzz.V('1', '+15V', fuzz.gnd, 'DC 15')
fuzz.V('3', 'IN', fuzz.gnd, 'DC 0V AC 0V PULSE(-0.5V +0.5V 0 0 0 2m 4m)')

class VoltageDivider(SubCircuitFactory):
    __name__ = 'voltage_divider'
    __nodes__ = ('n1', 'n2', 'n3' )
    def __init__(self, R=100@u_kΩ, w=0.4):
        super().__init__()
        self.R(1, 'n1', 'n2', R * w)
        self.R(2, 'n2', 'n3', R * (1.0-w) )

fuzz.subcircuit(VoltageDivider(R=100@u_kΩ, w=0.5))

simulator = fuzz.simulator(temperature=25, nominal_temperature=25)
analysis_fuzz_square = simulator.transient(step_time=1@u_us, start_time=100@u_ms, end_time=110@u_ms)
# Out:
# 2020-11-07 12:52:02,052 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - desk
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/BC547.mod
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 50.0kOhm
# R2 n2 n3 50.0kOhm
# .ends voltage_divider
# XU1 Net-_R2-Pad1_ Net-_C2-Pad2_ Net-_R4-Pad1_ Net-_RV1-Pad2_ Net-_C3-Pad1_ Net-_C4-Pad2_ GND Net-_C6-Pad1_ Net-_C6-Pad2_ Net-_C9-Pad2_ Net-_R11-Pad1_ GND GND +5V CD4069UBhex
# R1 IN GND 1Meg
# R2 Net-_R2-Pad1_ Net-_C1-Pad1_ 470k
# R3 Net-_C2-Pad2_ Net-_R2-Pad1_ 470k
# R4 Net-_R4-Pad1_ Net-_C2-Pad1_ 100k
# C1 Net-_C1-Pad1_ IN 10n
# C2 Net-_C2-Pad1_ Net-_C2-Pad2_ 2.2n
# R5 Net-_R5-Pad1_ Net-_R4-Pad1_ 100k
# XRV1 Net-_R5-Pad1_ Net-_RV1-Pad2_ Net-_R6-Pad2_ voltage_divider_1
# R6 Net-_C3-Pad2_ Net-_R6-Pad2_ 10k
# C3 Net-_C3-Pad1_ Net-_C3-Pad2_ 470n
# R7 Net-_C4-Pad2_ Net-_C3-Pad1_ 1Meg
# D2 Net-_C3-Pad1_ Net-_C4-Pad2_ D1N4148
# D1 Net-_C4-Pad2_ Net-_C3-Pad1_ D1N4148
# R8 Net-_C5-Pad2_ Net-_C4-Pad1_ 100k
# C4 Net-_C4-Pad1_ Net-_C4-Pad2_ 100n
# C5 GND Net-_C5-Pad2_ 1.5n
# R9 Net-_R9-Pad1_ Net-_C5-Pad2_ 10k
# XRV2 Net-_C6-Pad2_ Net-_C6-Pad2_ Net-_R9-Pad1_ voltage_divider_2
# C6 Net-_C6-Pad1_ Net-_C6-Pad2_ 150p
# R10 Net-_C6-Pad1_ Net-_C5-Pad2_ 100k
# R11 Net-_R11-Pad1_ Net-_C7-Pad1_ 100k
# C7 Net-_C7-Pad1_ Net-_C6-Pad1_ 100n
# R13 Net-_C9-Pad2_ Net-_R11-Pad1_ 220k
# C9 OUT Net-_C9-Pad2_ 100n
# C8 Net-_C8-Pad1_ Net-_C2-Pad2_ 100n
# R12 Net-_R11-Pad1_ Net-_C8-Pad1_ 100k
# R14 GND OUT 1k
# V1 +15V 0 DC 15
# V3 IN 0 DC 0V AC 0V PULSE(-0.5V +0.5V 0 0 0 2m 4m)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-07 12:52:02,053 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: destroy all
# 2020-11-07 12:52:02,063 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.load_circuit - DEBUG - ngSpice_Circ
# .title KiCad schematic
# .include /home/etienne/Documents/elektrophon/lib/spice/transistor/BC547.mod
# .subckt voltage_divider n1 n2 n3
# R1 n1 n2 50.0kOhm
# R2 n2 n3 50.0kOhm
# .ends voltage_divider
# XU1 Net-_R2-Pad1_ Net-_C2-Pad2_ Net-_R4-Pad1_ Net-_RV1-Pad2_ Net-_C3-Pad1_ Net-_C4-Pad2_ GND Net-_C6-Pad1_ Net-_C6-Pad2_ Net-_C9-Pad2_ Net-_R11-Pad1_ GND GND +5V CD4069UBhex
# R1 IN GND 1Meg
# R2 Net-_R2-Pad1_ Net-_C1-Pad1_ 470k
# R3 Net-_C2-Pad2_ Net-_R2-Pad1_ 470k
# R4 Net-_R4-Pad1_ Net-_C2-Pad1_ 100k
# C1 Net-_C1-Pad1_ IN 10n
# C2 Net-_C2-Pad1_ Net-_C2-Pad2_ 2.2n
# R5 Net-_R5-Pad1_ Net-_R4-Pad1_ 100k
# XRV1 Net-_R5-Pad1_ Net-_RV1-Pad2_ Net-_R6-Pad2_ voltage_divider_1
# R6 Net-_C3-Pad2_ Net-_R6-Pad2_ 10k
# C3 Net-_C3-Pad1_ Net-_C3-Pad2_ 470n
# R7 Net-_C4-Pad2_ Net-_C3-Pad1_ 1Meg
# D2 Net-_C3-Pad1_ Net-_C4-Pad2_ D1N4148
# D1 Net-_C4-Pad2_ Net-_C3-Pad1_ D1N4148
# R8 Net-_C5-Pad2_ Net-_C4-Pad1_ 100k
# C4 Net-_C4-Pad1_ Net-_C4-Pad2_ 100n
# C5 GND Net-_C5-Pad2_ 1.5n
# R9 Net-_R9-Pad1_ Net-_C5-Pad2_ 10k
# XRV2 Net-_C6-Pad2_ Net-_C6-Pad2_ Net-_R9-Pad1_ voltage_divider_2
# C6 Net-_C6-Pad1_ Net-_C6-Pad2_ 150p
# R10 Net-_C6-Pad1_ Net-_C5-Pad2_ 100k
# R11 Net-_R11-Pad1_ Net-_C7-Pad1_ 100k
# C7 Net-_C7-Pad1_ Net-_C6-Pad1_ 100n
# R13 Net-_C9-Pad2_ Net-_R11-Pad1_ 220k
# C9 OUT Net-_C9-Pad2_ 100n
# C8 Net-_C8-Pad1_ Net-_C2-Pad2_ 100n
# R12 Net-_R11-Pad1_ Net-_C8-Pad1_ 100k
# R14 GND OUT 1k
# V1 +15V 0 DC 15
# V3 IN 0 DC 0V AC 0V PULSE(-0.5V +0.5V 0 0 0 2m 4m)
# .options TEMP = 25C
# .options TNOM = 25C
# .ic
# .tran 1us 110ms 100ms
# .end
#
# 2020-11-07 12:52:02,067 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b"stderr warning, can't find model d1n4148"
# 2020-11-07 12:52:02,070 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - warning, can't find model d1n4148
# 2020-11-07 12:52:02,075 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b"stderr warning, can't find model d1n4148"
# 2020-11-07 12:52:02,079 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - warning, can't find model d1n4148
# 2020-11-07 12:52:02,084 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Circuit: KiCad schematic'
# 2020-11-07 12:52:02,086 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stderr Error: unknown subckt: xu1 net-_r2-pad1_ net-_c2-pad2_ net-_r4-pad1_ net-_rv1-pad2_ net-_c3-pad1_ net-_c4-pad2_ 0 net-_c6-pad1_ net-_c6-pad2_ net-_c9-pad2_ net-_r11-pad1_ 0 0 +5v cd4069ubhex'
# 2020-11-07 12:52:02,087 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Error: unknown subckt: xu1 net-_r2-pad1_ net-_c2-pad2_ net-_r4-pad1_ net-_rv1-pad2_ net-_c3-pad1_ net-_c4-pad2_ 0 net-_c6-pad1_ net-_c6-pad2_ net-_c9-pad2_ net-_r11-pad1_ 0 0 +5v cd4069ubhex
# 2020-11-07 12:52:02,090 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.exec_command - DEBUG - Execute command: run
# 2020-11-07 12:52:02,095 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Doing analysis at TEMP = 25.000000 and TNOM = 25.000000'
# 2020-11-07 12:52:02,099 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Initial Transient Solution'
# 2020-11-07 12:52:02,101 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout --------------------------'
# 2020-11-07 12:52:02,102 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout Node                                   Voltage'
# 2020-11-07 12:52:02,104 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout ----                                   -------'
# 2020-11-07 12:52:02,107 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c2-pad2_                          2.10156'
# 2020-11-07 12:52:02,110 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r2-pad1_                          2.10156'
# 2020-11-07 12:52:02,116 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout +5v                                          5'
# 2020-11-07 12:52:02,117 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_rv1-pad2_                         2.10156'
# 2020-11-07 12:52:02,119 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r4-pad1_                          2.10156'
# 2020-11-07 12:52:02,121 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c4-pad2_                          2.10156'
# 2020-11-07 12:52:02,129 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c3-pad1_                          2.10156'
# 2020-11-07 12:52:02,130 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c6-pad1_                          2.10156'
# 2020-11-07 12:52:02,134 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c6-pad2_                          2.10156'
# 2020-11-07 12:52:02,142 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c9-pad2_                          2.10156'
# 2020-11-07 12:52:02,144 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r11-pad1_                         2.10156'
# 2020-11-07 12:52:02,147 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout in                                           0'
# 2020-11-07 12:52:02,149 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c1-pad1_                          2.10156'
# 2020-11-07 12:52:02,151 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c2-pad1_                          2.10156'
# 2020-11-07 12:52:02,152 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r5-pad1_                          2.10156'
# 2020-11-07 12:52:02,157 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r6-pad2_                          2.10156'
# 2020-11-07 12:52:02,160 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c3-pad2_                          2.10156'
# 2020-11-07 12:52:02,162 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c5-pad2_                          2.10156'
# 2020-11-07 12:52:02,164 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c4-pad1_                          2.10156'
# 2020-11-07 12:52:02,165 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_r9-pad1_                          2.10156'
# 2020-11-07 12:52:02,166 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c7-pad1_                          2.10156'
# 2020-11-07 12:52:02,171 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout out                                          0'
# 2020-11-07 12:52:02,174 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout net-_c8-pad1_                          2.10156'
# 2020-11-07 12:52:02,176 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v2#branch                                    0'
# 2020-11-07 12:52:02,180 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout v1#branch                          -0.00286148'
# 2020-11-07 12:52:05,315 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.00000e-01\r'
# 2020-11-07 12:52:05,564 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b' Reference value :  1.08287e-01\r'
# 2020-11-07 12:52:05,645 - PySpice.Spice.NgSpice.Shared._send_char - DEBUG - b'stdout No. of Data Rows : 10001'
# 2020-11-07 12:52:05,646 - PySpice.Spice.NgSpice.Shared.NgSpiceShared.run - DEBUG - Simulation is done
# 2020-11-07 12:52:05,647 - PySpice.Spice.NgSpice.Simulation.NgSpiceSharedCircuitSimulator._run - DEBUG - ['tran1', 'const']

# %%
#plot the results
fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, sharex=False, figsize=(18, 6))

#plot the image
#img_diffpair_path = directory_path.joinpath('diffpair', 'diffpair.png')
#img_diffpair = mpimg.imread(str(img_diffpair_path))
#im = ax0.imshow(img_diffpair)
#ax0.axis('off')
#ax0.set_title('long tailed pair differential amplifier', y=-0.2)
        
#plot with envelope
ax1.plot(analysis_fuzz_sine['IN'].abscissa*1000, analysis_fuzz_sine['IN'], c='grey')  # envelope input (scaled)
ax1.plot(analysis_fuzz_sine['OUT'].abscissa*1000, analysis_fuzz_sine['OUT'], c='orange')  # differential output
ax1.grid()
ax1.set_xlabel('t [ms]')
ax1.set_ylabel('[V]')
ax1.set_title('output with a cv envelope', y=-0.2)

#plot with envelope
ax2.plot(analysis_fuzz_square['IN'].abscissa*1000, analysis_fuzz_square['IN'], c='grey')  # envelope input (scaled)
ax2.plot(analysis_fuzz_square['OUT'].abscissa*1000, analysis_fuzz_square['OUT'], c='orange')  # differential output
ax2.grid()
ax2.set_xlabel('t [ms]')
ax2.set_ylabel('[V]')
ax2.set_title('output with a cv envelope', y=-0.2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c19b33eb5443> in <module>
#      10
#      11 #plot with envelope
# ---> 12 ax1.plot(analysis_fuzz_sine['IN'].abscissa*1000, analysis_fuzz_sine['IN'], c='grey')  # envelope input (scaled)
#      13 ax1.plot(analysis_fuzz_sine['OUT'].abscissa*1000, analysis_fuzz_sine['OUT'], c='orange')  # differential output
#      14 ax1.grid()
#
# NameError: name 'analysis_fuzz_sine' is not defined

# %% [markdown]
# more promising is it to use a four quadrant multiplier, also known as gilbert cell. the gilbert cell is designed around two differential amplifiers. the carrier signal switches between those. the result is a multiplication of the input voltages. the gilbert cell is mostly used for amplitude modulation in radio transmission. if you look at the integratd circuits like the 633 it can modulate signals up in the gigahertz range. the gilbert cell is not described in all details here, there is a good introduction from w2aew [[4][4]].

# %% [markdown]
# this is not real amplitude modulation. when the signal is negative the phase of the output is inverted. this can be adjusted by the bias voltage of the control voltage. the control voltage has to be positive at all time.

# %% [markdown]
# ## *construction*
#
# for the final circuit input and output buffering and biasing is needed. the buffering is done with opamps.

# %% [markdown]
# first we design the input stage. the input voltage for the X signal should be 10mV and 20mV for the control voltage.

# %% [markdown]
# ## *references*
#
# - [VCA Techniques Investigated][1] Rod Elliott (ESP)
# - [Popular Electronics][2] Keyiing and VCA citcuits for electronic music instruments
# - [VCA-1][3] Thomas Henry CA3080 vca
# - [VCA-3][4] René Schmitz differential pair vca
# - [#223][5]: Basics of the Gilbert Cell | Analog Multiplier | Mixer | Modulator
# - [#224][6]: AM & DSB-SC Modulation with the Gilbert Cell
# - [Analog Devices][8]: Analog multiplier application guide
# - [AD633][9]: Datasheet
#
#
#
#
# [1]: http://www.runoffgroove.com/ubescreamer.html
# [2]: https://www.diystompboxes.com/smfforum/index.php?topic=118397.0
# [3]: https://www.diystompboxes.com/smfforum/index.php?topic=99779.0
