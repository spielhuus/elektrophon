# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import matplotlib.pyplot as plt
import numpy as np

import PySpice.Logging.Logging as Logging
logger = Logging.setup_logging( logging_level='INFO')

import os
import sys
from pathlib import Path
import IPython.display as ipd
from PySpice.Unit import *
from PySpice.Spice.Parser import SpiceParser
from PySpice.Spice.Netlist import Circuit, SubCircuit, SubCircuitFactory
from PySpice.Spice.Library import SpiceLibrary
from PySpice.Probe.Plot import plot
from PySpice.Doc.ExampleTools import find_libraries
from PySpice.Math import *
from PySpice.Plot.BodeDiagram import bode_diagram
from PySpice.Plot.BodeDiagram import bode_diagram_gain

import schemdraw
import schemdraw.elements as elm
from schemdraw import logic

directory_path = Path(os.path.abspath('')).resolve().parent.parent
spice_libraries_path = directory_path.joinpath("lib", "spice")
spice_library = SpiceLibrary(spice_libraries_path)
# Out:
# 2021-03-28 11:08:15,320 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VCC_ABS_MAX = 20
# 2021-03-28 11:08:15,321 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VCC_MAX = 18
# 2021-03-28 11:08:15,322 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM RA = 720000000
# 2021-03-28 11:08:15,322 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM RB = 720000000
# 2021-03-28 11:08:15,323 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM CA = 4.5e-12
# 2021-03-28 11:08:15,325 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM CB = 4.5e-12
# 2021-03-28 11:08:15,326 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM ROEZ = 2000
# 2021-03-28 11:08:15,327 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM COEZ = 3e-12
# 2021-03-28 11:08:15,329 - PySpice.Spice.Parser.Element.read_words - WARNING - Bad element line, looking for word 1/2:
# SICC VCC GND VCC GND SW1
#                          ^
# 2021-03-28 11:08:15,330 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parse error on:
# SICC VCC GND VCC GND SW1
# 2021-03-28 11:08:15,332 - PySpice.Spice.Parser.Element.read_words - WARNING - Bad element line, looking for word 1/2:
# SIOFF OUTsw OUT VCC GND SW2
#                             ^
# 2021-03-28 11:08:15,333 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parse error on:
# SIOFF OUTsw OUT VCC GND SW2
# 2021-03-28 11:08:15,334 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM STANDARD_INPUT_SELECT = 0
# 2021-03-28 11:08:15,336 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM SCHMITT_TRIGGER_INPUT_SELECT = 1
# 2021-03-28 11:08:15,338 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM MAXICC = 0.0009
# 2021-03-28 11:08:15,339 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VT = .7
# 2021-03-28 11:08:15,340 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VCC_MIN = 3
# 2021-03-28 11:08:15,342 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM AND  = 0
# 2021-03-28 11:08:15,343 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM NAND = 1
# 2021-03-28 11:08:15,344 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM OR   = 0
# 2021-03-28 11:08:15,347 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM NOR  = 0
# 2021-03-28 11:08:15,349 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM XOR  = 0
# 2021-03-28 11:08:15,350 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM XNOR = 0
# 2021-03-28 11:08:15,352 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM TPDELAY1 = 1N
# 2021-03-28 11:08:15,352 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM RS = 10K
# 2021-03-28 11:08:15,353 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM CS = {-TPDELAY1/(RS*LOG(0.5))}
# 2021-03-28 11:08:15,356 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VCC1 = 1.65
# 2021-03-28 11:08:15,358 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VCC2 = 2.3
# 2021-03-28 11:08:15,359 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VCC3 = 3
# 2021-03-28 11:08:15,361 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VCC4 = 3
# 2021-03-28 11:08:15,364 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VCC5 = 4.5
# 2021-03-28 11:08:15,365 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VOL1 = 0.45
# 2021-03-28 11:08:15,367 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VOL2 = 0.3
# 2021-03-28 11:08:15,371 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VOL3 = 0.4
# 2021-03-28 11:08:15,373 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VOL4 = 0.55
# 2021-03-28 11:08:15,375 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VOL5 = 0.55
# 2021-03-28 11:08:15,378 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM IOL1 = 0.004
# 2021-03-28 11:08:15,384 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM IOL2 = 0.008
# 2021-03-28 11:08:15,385 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM IOL3 = 0.016
# 2021-03-28 11:08:15,387 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM IOL4 = 0.024
# 2021-03-28 11:08:15,388 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM IOL5 = 0.032
# 2021-03-28 11:08:15,390 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM RO
- PySpice.Spice.Parser.Element.read_words - WARNING - Bad element line, looking for word 1/2:
# SIOFF OUTsw OUT VCC GND SW2
#                             ^
# 2021-03-28 11:08:15,512 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parse error on:
# SIOFF OUTsw OUT VCC GND SW2
# 2021-03-28 11:08:15,514 - PySpice.Spice.Parser.Element.read_words - WARNING - Bad element line, looking for word 1/2:
# SDA1 NA1 A VCC GND SW2
#                    ^
# 2021-03-28 11:08:15,516 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parse error on:
# SDA1 NA1 A VCC GND SW2
# 2021-03-28 11:08:15,518 - PySpice.Spice.Parser.Element.read_words - WARNING - Bad element line, looking for word 1/2:
# SDB1 NB1 B VCC GND SW2
#                    ^
# 2021-03-28 11:08:15,519 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parse error on:
# SDB1 NB1 B VCC GND SW2
# 2021-03-28 11:08:15,521 - PySpice.Spice.Parser.Element.read_words - WARNING - Bad element line, looking for word 1/2:
# SDO1 NO1 OUT VCC GND SW2
#                      ^
# 2021-03-28 11:08:15,523 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parse error on:
# SDO1 NO1 OUT VCC GND SW2
# 2021-03-28 11:08:15,526 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM STANDARD_INPUT_SELECT = 0
# 2021-03-28 11:08:15,530 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM SCHMITT_TRIGGER_INPUT_SELECT = 1
# 2021-03-28 11:08:15,535 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM MAXICC = 0.0009
# 2021-03-28 11:08:15,536 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VT = .7
# 2021-03-28 11:08:15,546 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VCC_MIN = 4.5
# 2021-03-28 11:08:15,551 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM AND  = 0
# 2021-03-28 11:08:15,556 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM NAND = 1
# 2021-03-28 11:08:15,558 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM OR   = 0
# 2021-03-28 11:08:15,561 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM NOR  = 0
# 2021-03-28 11:08:15,562 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM XOR  = 0
# 2021-03-28 11:08:15,563 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM XNOR = 0
# 2021-03-28 11:08:15,565 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM TPDELAY1 = 1N
# 2021-03-28 11:08:15,567 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM RS = 10K
# 2021-03-28 11:08:15,568 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM CS = {-TPDELAY1/(RS*LOG(0.5))}
# 2021-03-28 11:08:15,569 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM ICC = 1.25e-05
# 2021-03-28 11:08:15,576 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VCC_MAX = 5.5
# 2021-03-28 11:08:15,578 - PySpice.Spice.Parser.SpiceParser._parse - WARNING - Parser ignored: .PARAM VCC_MIN = 4.5

# %% [markdown]
# the CD4069UB device consist of six CMOS inverter circuits. these devices are intended for all generalpurpose inverter applications where the mediumpower TTL-drive and logic-level-conversion. this device is not ideal for linear amplification, but can be used as such and will add a lot of soft-clipping. soft-clipping is expected from a valve. this makes this device special for musical usage and can be found in guitar distortion pedals [[2](http://www.runoffgroove.com/ubescreamer.html)] or the wasp filter [[3](https://www.schmitzbits.de/wasp.html)]. in this article series i want to investigate this device and find out if new modules can be built with it.
#
# the chip should be powered by +5V/GND. With higher voltage the heat dissipation will be to big and the chip will be damaged. the chip is powered on pin 7 and 14 with +5V and Ground. the other pins can be used as amplifier.

# %%
d = schemdraw.Drawing(unit=2.5, inches_per_unit=0.5, lw=0.9)
d += (Q := elm.IcDIP(pins=14, botlabel='CD40106', lw=2)
             .label('Input A', loc='p1', fontsize=10)
             .label('Output A', loc='p2', fontsize=10)
             .label('Input B', loc='p3', fontsize=10)
             .label('Output B', loc='p4', fontsize=10)
             .label('Input C', loc='p5', fontsize=10)
             .label('Output C', loc='p6', fontsize=10)
             .label('GND', loc='p7', fontsize=10)

             .label('Output D', loc='p8', fontsize=10)
             .label('Input D', loc='p9', fontsize=10)
             .label('Output E', loc='p10', fontsize=10)
             .label('Input E', loc='p11', fontsize=10)
             .label('Output F', loc='p12', fontsize=10)
             .label('Input F', loc='p13', fontsize=10)
             .label('$V_{dd}$', loc='p14', fontsize=10))

d += elm.Line().at(Q.p1_in).length(d.unit/4)
d += (op := logic.Schmitt("down").toy(Q.p2_in).anchor('start').scale(.8))
d += elm.Line("right").at(Q.p2_in).length(d.unit/4)

d += elm.Line().at(Q.p3_in).length(d.unit/4)
d += (op := logic.Schmitt("down").toy(Q.p4_in).anchor('start').scale(.8))
d += elm.Line("right").at(Q.p4_in).length(d.unit/4)

d += elm.Line().at(Q.p5_in).length(d.unit/4)
d += (op := logic.Schmitt("down").toy(Q.p6_in).anchor('start').scale(.8))
d += elm.Line("right").at(Q.p6_in).length(d.unit/4)

d += elm.Line("left").at(Q.p8_in).length(d.unit/4)
d += (op := logic.Schmitt("up").toy(Q.p9_in).anchor('start').scale(.8))
d += elm.Line("left").at(Q.p9_in).length(d.unit/4)

d += elm.Line("left").at(Q.p10_in).length(d.unit/4)
d += (op := logic.Schmitt("up").toy(Q.p11_in).anchor('start').scale(.8))
d += elm.Line("left").at(Q.p11_in).length(d.unit/4)

d += elm.Line("left").at(Q.p12_in).length(d.unit/4)
d += (op := logic.Schmitt("up").toy(Q.p13_in).anchor('start').scale(.8))
d += elm.Line("left").at(Q.p13_in).length(d.unit/4)

d.draw()

# %% [markdown]
# # voltage follower
# {: class="subtitle is-lowercase"}
#
# the simplest circuit to begin with is a voltage follower or buffer. the buffer confifuration looks similar to the opamp buffer. but there are some differences. the first important difference is that the feedback will also do the biasing of the input signal. when an ac signal is applied to the buffer the output will be a dc signal, as long as the chip is able to provide the needed biasing feedback. the gain can be calculated similar to the opamp configuration. but there will be less gain as we would excpect from the calculation.

# %%
d = schemdraw.Drawing(unit=2.5, inches_per_unit=0.5, lw=0.9)
d.add(elm.Dot('left', lftlabel='IN', open=True))
R = d.add(elm.Resistor(label='$R_1$\n100k'))
d.add(elm.Capacitor(label='$C_1$\n47n'))
N = d.add(logic.Not)
C = d.add(elm.Capacitor(label='$C_2$\n10u'))
d.add(elm.Resistor("down",label='$R_{load}$'))
d.add(elm.Ground)

d.add(logic.Dot(xy=N.start))
d.add(elm.Line('up', l=d.unit/2))
d.add(elm.Resistor('right', label='$R_2$\n100k'))
d.add(elm.Line('down', l=d.unit/2))
d.add(logic.Dot())

d.add(logic.Dot(xy=C.end))
d.add(elm.Line('right', l=d.unit/2))
d.add(elm.Dot('right', rgtlabel='OUT', open=True))

d.draw()

# %% [markdown]
# This is the first setup with the 4069 as voltage follower. C1 and C3 are the dc blocking capacitors. When we choose R1 and R2 as 100kOhm we would excpect a gain of one.

# %%
circuit = Circuit('cmos gate')
circuit.include(spice_library['4069UB'])
circuit.include(spice_library['CD40106B'])

circuit.V('1', '+5V', circuit.gnd, 'DC 5')
circuit.V('2', 'IN', circuit.gnd, 'DC 5 AC 2.5V SIN(2.5 2.5V 100)')


circuit.X('1', 'CD40106B', 'OUT', 'IN', '+5V', circuit.gnd)
#circuit.R(1, 'Xout', 'X1', 100@u_kΩ)
#circuit.C(1, 'X1', circuit.gnd, 10@u_nF)
#circuit.R(1, 'R1out', 'IN', 100@u_kΩ)
#circuit.C(2, 'Xout', 'OUT', 1@u_uF)
#R = circuit.R('load', 'OUT', circuit.gnd, 100@u_kΩ)
# Out:
# SubCircuitElement X1

# %%
simulator = circuit.simulator(temperature=25, nominal_temperature=25)
analysis  = simulator.transient(step_time=1@u_us, start_time=0@u_ms, end_time=30@u_ms)
# Out:
# 2021-03-28 11:08:17,495 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Note: Star
- PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  88.4788% Note: One successful source step
# 2021-03-28 11:08:17,815 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  89.9788% Note: One successful source step
# 2021-03-28 11:08:17,818 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  92.2288% Note: One successful source step
# 2021-03-28 11:08:17,819 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  95.6038% Note: One successful source step
# 2021-03-28 11:08:17,822 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to 100.0000% Note: One successful source step
# 2021-03-28 11:08:17,824 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Note: Source stepping completed
# ---------------------------------------------------------------------------
# NgSpiceCommandError                       Traceback (most recent call last)
# <ipython-input-5-b1fd42813209> in <module>
#       1 simulator = circuit.simulator(temperature=25, nominal_temperature=25)
# ----> 2 analysis  = simulator.transient(step_time=1@u_us, start_time=0@u_ms, end_time=30@u_ms)
#
# ~/anaconda3/envs/elektrophon/lib/python3.9/site-packages/PySpice/Spice/Simulation.py in transient(self, *args, **kwargs)
#    1164
#    1165     def transient(self, *args, **kwargs):
# -> 1166         return self._run('transient', *args, **kwargs)
#    1167
#    1168     ##############################################
#
# ~/anaconda3/envs/elektrophon/lib/python3.9/site-packages/PySpice/Spice/NgSpice/Simulation.py in _run(self, analysis_method, *args, **kwargs)
#     116         # Fixme: Error: circuit not parsed.
#     117         self._ngspice_shared.load_circuit(str(self))
# --> 118         self._ngspice_shared.run()
#     119         self._logger.debug(str(self._ngspice_shared.plot_names))
#     120         self.reset_analysis()
#
# ~/anaconda3/envs/elektrophon/lib/python3.9/site-packages/PySpice/Spice/NgSpice/Shared.py in run(self, background)
#    1166
#    1167         command = 'bg_run' if background else 'run'
# -> 1168         self.exec_command(command)
#    1169
#    1170         if background:
#
# ~/anaconda3/envs/elektrophon/lib/python3.9/site-packages/PySpice/Spice/NgSpice/Shared.py in exec_command(self, command, join_lines)
#     840
#     841         if self._error_in_stdout or self._error_in_stderr:
# --> 842             raise NgSpiceCommandError("Command '{}' failed".format(command))
#     843
#     844         if join_lines:
#
# NgSpiceCommandError: Command 'run' failed

# %%
fig_buffer, ax1_buffer = plt.subplots()

ax1_buffer.set_xlabel('time (ms)')
ax1_buffer.set_ylabel('IN [V]')
ax1_buffer.plot(u_ms(analysis['IN'].abscissa), analysis['IN'], color='Blue')
ax1_buffer.plot(u_ms(analysis['OUT'].abscissa), analysis['OUT'], color='Red')
ax1_buffer.legend(('IN [V]', 'OUT [V]'), loc=(0.78,0.8))

plt.tight_layout()
plt.show()

# %% [markdown]
# The blue line is the input signal (5V p2p) and the red the output signal with 100kOhm resistors. The output is a little less then excpected. For the other signals the resistor R2 is replaced with 125kΩ, 150kΩ, 175kΩ and 200kΩ. With 150kΩ the gain is roughly one. We also see that the ouput is not symetrical. The clipping occures earlier for the negative part of the signal. With higher gain the signal is soft clipped.

# %%
circuit = Circuit('cmos oscillator')
circuit.include(spice_library['4069UB'])
circuit.include(spice_library['CD40106B'])

circuit.V('1', '+5V', circuit.gnd, 'DC 5')

circuit.X('1', 'CD40106B', 'XOUT', 'IN', '+5V', circuit.gnd)
#circuit.R(1, 'IN', 'XOUT', 500@u_kΩ)
circuit.C(1, 'IN', circuit.gnd, 0.1@u_uF)
#circuit.R(2, 'IN', circuit.gnd, 100@u_kΩ)
circuit.R('load', 'XOUT', circuit.gnd, 100@u_kΩ)

simulator = circuit.simulator(temperature=25, nominal_temperature=25)
analysis  = simulator.transient(step_time=10@u_us, start_time=0@u_ms, end_time=20@u_ms)

fig_buffer, ax1_buffer = plt.subplots()

ax1_buffer.set_xlabel('time (ms)')
ax1_buffer.set_ylabel('IN [V]')
ax1_buffer.plot(u_ms(analysis['IN'].abscissa), analysis['IN'], color='Blue')
ax1_buffer.plot(u_ms(analysis['XOUT'].abscissa), analysis['XOUT'], color='Red')
ax1_buffer.legend(('IN [V]', 'OUT [V]'), loc=(0.78,0.8))

plt.tight_layout()
plt.show()
# Out:
# 2021-03-28 11:08:53,898 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Note: Star
- PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  10.3278% Note: One successful source step
# 2021-03-28 11:08:54,503 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  12.2740% Supplies reduced to  10.3278% Note: One successful source step
# 2021-03-28 11:08:54,505 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  10.6197% Note: One successful source step
# 2021-03-28 11:08:54,512 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.0576% Note: One successful source step
# 2021-03-28 11:08:54,529 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.7144% Supplies reduced to  11.0576% Note: One successful source step
# 2021-03-28 11:08:54,537 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.1561% Note: One successful source step
# 2021-03-28 11:08:54,551 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.3039% Supplies reduced to  11.1561% Note: One successful source step
# 2021-03-28 11:08:54,553 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.1783% Note: One successful source step
# 2021-03-28 11:08:54,555 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.2115% Note: One successful source step
# 2021-03-28 11:08:54,558 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.2614% Note: One successful source step
# 2021-03-28 11:08:54,573 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.3362% Supplies reduced to  11.2614% Note: One successful source step
# 2021-03-28 11:08:54,575 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.2726% Note: One successful source step
# 2021-03-28 11:08:54,577 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.2895% Note: One successful source step
# 2021-03-28 11:08:54,592 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.3147% Supplies reduced to  11.2895% Note: One successful source step
# 2021-03-28 11:08:54,597 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.2933% Note: One successful source step
# 2021-03-28 11:08:54,598 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.2989% Note: One successful source step
# 2021-03-28 11:08:54,608 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.3075% Supplies reduced to  11.2989% Note: One successful source step
# 2021-03-28 11:08:54,619 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.3002% Supplies reduced to  11.2989% Note: One successful source step
# 2021-03-28 11:08:54,620 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.2991% Note: One successful source step
# 2021-03-28 11:08:54,621 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.2994% Note: One successful source step
# 2021-03-28 11:08:54,634 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.2998% Supplies reduced to  11.2994% Note: One successful source step
# 2021-03-28 11:08:54,646 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - Supplies reduced to  11.2995% Warning: source stepping failed
# 2021-03-28 11:08:54,654 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - doAnalyses: Too many iterations without convergence
# 2021-03-28 11:08:54,655 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._send_char - ERROR - run simulation(s) aborted
# ---------------------------------------------------------------------------
# NgSpiceCommandError                       Traceback (most recent call last)
# <ipython-input-6-7df75d2ca281> in <module>
#      12
#      13 simulator = circuit.simulator(temperature=25, nominal_temperature=25)
# ---> 14 analysis  = simulator.transient(step_time=10@u_us, start_time=0@u_ms, end_time=20@u_ms)
#      15
#      16 fig_buffer, ax1_buffer = plt.subplots()
#
# ~/anaconda3/envs/elektrophon/lib/python3.9/site-packages/PySpice/Spice/Simulation.py in transient(self, *args, **kwargs)
#    1164
#    1165     def transient(self, *args, **kwargs):
# -> 1166         return self._run('transient', *args, **kwargs)
#    1167
#    1168     ##############################################
#
# ~/anaconda3/envs/elektrophon/lib/python3.9/site-packages/PySpice/Spice/NgSpice/Simulation.py in _run(self, analysis_method, *args, **kwargs)
#     116         # Fixme: Error: circuit not parsed.
#     117         self._ngspice_shared.load_circuit(str(self))
# --> 118         self._ngspice_shared.run()
#     119         self._logger.debug(str(self._ngspice_shared.plot_names))
#     120         self.reset_analysis()
#
# ~/anaconda3/envs/elektrophon/lib/python3.9/site-packages/PySpice/Spice/NgSpice/Shared.py in run(self, background)
#    1166
#    1167         command = 'bg_run' if background else 'run'
# -> 1168         self.exec_command(command)
#    1169
#    1170         if background:
#
# ~/anaconda3/envs/elektrophon/lib/python3.9/site-packages/PySpice/Spice/NgSpice/Shared.py in exec_command(self, command, join_lines)
#     840
#     841         if self._error_in_stdout or self._error_in_stderr:
# --> 842             raise NgSpiceCommandError("Command '{}' failed".format(command))
#     843
#     844         if join_lines:
#
# NgSpiceCommandError: Command 'run' failed

# %% [markdown]
# # references
# {: class="subtitle is-lowercase"}
#
# 1. [CD40106](https://www.ti.com/lit/ds/symlink/cd40106b.pdf) Datasheet
